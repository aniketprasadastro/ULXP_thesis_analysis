# %%
import os
import subprocess
import numpy as np
from astropy.io import fits

# %%
# File to store the consolidated results for all light curves
consolidated_file = "all_lc_periods_chisq_py_lc_files_uncorrected.txt"

# Create or clear the consolidated file
with open(consolidated_file, "w") as f:
    f.write("LC_File_Path\tPeriod\tChi-square\tDate\n")

# Find all obsID folders in the "output" directory
#obsid_folders = [f.path for f in os.scandir("./reduced_output") if f.is_dir() and f.name.startswith("6050")]
obsid_folders = sorted(
    [f.path for f in os.scandir("./reduced_output") if f.is_dir() and f.name.startswith("6050")],
    key=lambda x: int(os.path.basename(x))
)

# Loop through each obsID folder
for obsid_folder in obsid_folders:
    obsid = os.path.basename(obsid_folder)
    print(f"Processing obsID: {obsid}")

    # Define the light curve file path
    lc_files = []
    for root, dirs, files in os.walk(obsid_folder):
        for file in files:
            if file.endswith("night_0.1.lc"):
                lc_files.append(os.path.join(root, file))

    # Check if any light curve files were found
    if not lc_files:
        print(f"No light curve files found for obsID: {obsid}")
        continue

    # Loop through each light curve file
    for lc_file in lc_files:
        print(f"Processing light curve: {lc_file}")
        
        # Define paths for output files
        lc_folder = os.path.dirname(lc_file)
        output_folder = os.path.join(lc_folder, "efsearch_output")
        os.makedirs(output_folder, exist_ok=True)
        output_fits = os.path.join(output_folder, "efsearch_lc_uncorrected.fes")

        # Construct the efsearch command
        efsearch_cmd = f'efsearch {lc_file} window=- sepoch=20112.43540056619 dper=9.80 nphase=64 nbint=INDEF dres=1e-4 nper=1024 plot=no outfile={output_fits}'

        try:
            # Run the efsearch command
            subprocess.run(efsearch_cmd, shell=True, check=True)

            # Open the .fes FITS file and extract the best-fit period
            with fits.open(output_fits) as efsearch_fits:
                # Extract data from the 'RESULTS' table
                results_data = efsearch_fits['RESULTS'].data
                max_chisq_index = np.argmax(results_data['CHISQRD1'])  # Get index of maximum chi-square
                best_fit_period = results_data['PERIOD'][max_chisq_index]
                chisq_max = results_data['CHISQRD1'][max_chisq_index]

                # Extract the observation start time (TSTARTI) from the FITS header
                tstarti = efsearch_fits['RESULTS'].header.get('TSTARTI', 'N/A')  # 'N/A' if the keyword is missing

            # Append the results to the consolidated file
            with open(consolidated_file, "a") as f_out:
                f_out.write(f"{obsid}\t{best_fit_period}\t{chisq_max}\t{tstarti}\n")
            print(f"Processed {lc_file}, Best-fit period: {best_fit_period}, Chi-square: {chisq_max}, TSTARTI: {tstarti}")

        except subprocess.CalledProcessError as e:
            print(f"Error processing {lc_file}: {e}")

print(f"All periods, chi-squares, and TSTARTI values saved to {consolidated_file}")
# Out:
# Processing obsID: 6050390261
# Processing light curve: ./reduced_output/6050390261/ni6050390261_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390261/ni6050390261_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20174 01:46:06.419
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20174 20:33:09.275
#  No. of Rows .......      1013193        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09193200E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14322300E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20174 01:46:06.419
#  No. of Rows .......            3        Last GTI Stop ..... 20174 20:33:09.275
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20174.07368540511  (days)       1:46: 6:419  (h:m:s:ms)
#  Expected Stop .... 20174.85635734769  (days)      20:33: 9:275  (h:m:s:ms)
#
#  Default Epoch is:  20174.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6900.29
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            441619
#
#  Default Newbins per Interval are:      441619
#  (giving       1 Interval of       441619 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       441619 Newbins of      0.153125     (s)
#  Default resolution is 0.7101143746E-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
#   Chisq. vs. period ready
#
#  Period :   9.793    dP/dt :   0.000
#  Intv    1   Start 20174  1:46: 6
#      Ser.1     Avg  511.8        Chisq 0.1712E+05   Var  4529.     Newbs.     64
#                Min  384.6          Max  601.9    expVar  16.88      Bins 993079
# Writing output file: ./reduced_output/6050390261/efsearch_output/testing_efsearc
# 100% completed
# Interval 2 rejected; all bins zero
#
#  Period :   9.793    dP/dt :   0.000
#  Intv    3   Start     0  0: 0: 0
#      Ser.1     Avg  0.000        Chisq  0.000       Var  0.000     Newbs.      0
#                Min 0.1000E+35      Max-0.1000E+35expVar  0.000      Bins     -1
#
# Frame ready : Writing in output : ./reduced_output/6050390261/efsearch_output/te
# Processed ./reduced_output/6050390261/ni6050390261_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.7925, Chi-square: 17117.1796875, TSTARTI: 20174
# Processing obsID: 6050390240
# Processing light curve: ./reduced_output/6050390240/ni6050390240_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390240/ni6050390240_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20125 14:10:58.826
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20125 17:26:32.353
#  No. of Rows .......      1929164        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09184500E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14319400E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20125 14:10:58.826
#  No. of Rows .......            3        Last GTI Stop ..... 20125 17:26:32.353
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20125.59095863260  (days)      14:10:58:826  (h:m:s:ms)
#  Expected Stop .... 20125.72676335046  (days)      17:26:32:353  (h:m:s:ms)
#
#  Default Epoch is:  20125.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           1197.30
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.             76628
#
#  Default Newbins per Interval are:       76628
#  (giving       1 Interval of        76628 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with        76628 Newbins of      0.153125     (s)
#  Default resolution is 0.4092498825E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
#   Chisq. vs. period ready
#
#  Period :   9.800    dP/dt :   0.000
#  Intv    1   Start 20125 14:10:58
#      Ser.1     Avg  1037.        Chisq 0.3348E+05   Var 0.1948E+05 Newbs.     64
#                Min  836.2          Max  1250.    expVar  37.25      Bins1846841
# Writing output file: ./reduced_output/6050390240/efsearch_output/testing_efsearc
# 100% completed
# Interval 2 rejected; all bins zero
#
#  Period :   9.800    dP/dt :   0.000
#  Intv    3   Start     0  0: 0: 0
#      Ser.1     Avg  0.000        Chisq  0.000       Var  0.000     Newbs.      0
#                Min 0.1000E+35      Max-0.1000E+35expVar  0.000      Bins     -1
#
# Frame ready : Writing in output : ./reduced_output/6050390240/efsearch_output/te
# Processed ./reduced_output/6050390240/ni6050390240_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.799700000000001, Chi-square: 33475.31640625, TSTARTI: 20125
# Processing obsID: 6050390251
# Processing light curve: ./reduced_output/6050390251/ni6050390251_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390251/ni6050390251_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20144 05:54:39.452
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20144 17:00:38.815
#  No. of Rows .......      2431950        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09161900E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14305700E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20144 05:54:39.452
#  No. of Rows .......            2        Last GTI Stop ..... 20144 17:00:38.815
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20144.24628995169  (days)       5:54:39:452  (h:m:s:ms)
#  Expected Stop .... 20144.70878258142  (days)      17: 0:38:815  (h:m:s:ms)
#
#  Default Epoch is:  20144.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           4077.49
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            260960
#
#  Default Newbins per Interval are:      260960
#  (giving       1 Interval of       260960 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       260960 Newbins of      0.153125     (s)
#  Default resolution is 0.1201716738E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.801    dP/dt :   0.000
#  Intv    1   Start 20144  5:54:39
#      Ser.1     Avg  1583.        Chisq 0.4967E+05   Var 0.5246E+05 Newbs.     64
#                Min  1262.          Max  1915.    expVar  67.60      Bins2431950
# Writing output file: ./reduced_output/6050390251/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390251/ni6050390251_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.8008, Chi-square: 49666.31640625, TSTARTI: 20144
# Processing obsID: 6050390249
# Processing light curve: ./reduced_output/6050390249/ni6050390249_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390249/ni6050390249_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20142 10:39:39.327
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20142 10:50:07.356
#  No. of Rows .......      1045756        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09175800E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14289400E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20142 10:39:39.327
#  No. of Rows .......            1        Last GTI Stop ..... 20142 10:50:07.356
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20142.44420516956  (days)      10:39:39:327  (h:m:s:ms)
#  Expected Stop .... 20142.45147402931  (days)      10:50: 7:356  (h:m:s:ms)
#
#  Default Epoch is:  20142.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..             64.08
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.              4102
#
#  Default Newbins per Interval are:        4102
#  (giving       1 Interval of         4102 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with         4102 Newbins of      0.153125     (s)
#  Default resolution is 0.7645051195E-01
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.793    dP/dt :   0.000
#  Intv    1   Start 20142 10:39:39
#      Ser.1     Avg  1461.        Chisq 0.1961E+05   Var 0.4571E+05 Newbs.     64
#                Min  1172.          Max  1818.    expVar  148.8      Bins1045756
# Writing output file: ./reduced_output/6050390249/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390249/ni6050390249_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.7933, Chi-square: 19606.267578125, TSTARTI: 20142
# Processing obsID: 6050390230
# Processing light curve: ./reduced_output/6050390230/ni6050390230_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390230/ni6050390230_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.             39272
#
#  Default Newbins per Interval are:       39272
#  (giving       1 Interval of        39272 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with        39272 Newbins of      0.153125     (s)
#  Default resolution is 0.7985333062E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.792    dP/dt :   0.000
#  Intv    1   Start 20187 18:12:16
#      Ser.1     Avg  131.8        Chisq  2128.       Var  323.7     Newbs.     64
#                Min  100.3          Max  172.1    expVar  9.656      Bins 124501
# Writing output file: ./reduced_output/6050390272/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390272/ni6050390272_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.792000000000002, Chi-square: 2128.31396484375, TSTARTI: 20187
# Processing obsID: 6050390254
# Processing light curve: ./reduced_output/6050390254/ni6050390254_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390254/ni6050390254_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20147 00:35:42.877
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20147 19:11:34.978
#  No. of Rows .......      3032655        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09173200E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14308500E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20147 00:35:42.877
#  No. of Rows .......            5        Last GTI Stop ..... 20147 19:11:34.978
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20147.02480181477  (days)       0:35:42:877  (h:m:s:ms)
#  Expected Stop .... 20147.79971039391  (days)      19:11:34:978  (h:m:s:ms)
#
#  Default Epoch is:  20147.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6831.85
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            437239
#
#  Default Newbins per Interval are:      437239
#  (giving       1 Interval of       437239 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       437239 Newbins of      0.153125     (s)
#  Default resolution is 0.7172278777E-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
#   Chisq. vs. period ready
#
#  Period :   9.796    dP/dt :   0.000
#  Intv    1   Start 20147  0:35:42
#      Ser.1     Avg  1572.        Chisq 0.5871E+05   Var 0.4915E+05 Newbs.     64
#                Min  1217.          Max  1877.    expVar  53.53      Bins2954075
# Writing output file: ./reduced_output/6050390254/efsearch_output/testing_efsearc
# 100% completed
# Interval 2 rejected; all bins zero
#
#  Period :   9.796    dP/dt :   0.000
#  Intv    3   Start     0  0: 0: 0
#      Ser.1     Avg  0.000        Chisq  0.000       Var  0.000     Newbs.      0
#                Min 0.1000E+35      Max-0.1000E+35expVar  0.000      Bins     -1
#
# Frame ready : Writing in output : ./reduced_output/6050390254/efsearch_output/te
# Processed ./reduced_output/6050390254/ni6050390254_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.795700000000002, Chi-square: 58712.6328125, TSTARTI: 20147
# Processing obsID: 6050390279
# Processing light curve: ./reduced_output/6050390279/ni6050390279_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390279/ni6050390279_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20195 04:16:17.441
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20195 10:35:58.028
#  No. of Rows .......       128642        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09183000E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14321000E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20195 04:16:17.441
#  No. of Rows .......            6        Last GTI Stop ..... 20195 10:35:58.028
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20195.17797964338  (days)       4:16:17:441  (h:m:s:ms)
#  Expected Stop .... 20195.44164383844  (days)      10:35:58: 28  (h:m:s:ms)
#
#  Default Epoch is:  20195.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           2324.55
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            148772
#
#  Default Newbins per Interval are:      148772
#  (giving       1 Interval of       148772 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       148772 Newbins of      0.153125     (s)
#  Default resolution is 0.2107923534E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.792    dP/dt :   0.000
#  Intv    1   Start 20195  4:16:17
#      Ser.1     Avg  55.85        Chisq  1406.       Var  35.89     Newbs.     64
#                Min  47.07          Max  66.64    expVar  1.633      Bins 128642
# Writing output file: ./reduced_output/6050390279/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390279/ni6050390279_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.7918, Chi-square: 1405.626708984375, TSTARTI: 20195
# Processing obsID: 6050390268
# Processing light curve: ./reduced_output/6050390268/ni6050390268_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390268/ni6050390268_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20183 10:24:55.507
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20183 10:35:11.560
#  No. of Rows .......       126417        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09188100E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14310000E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20183 10:24:55.507
#  No. of Rows .......            1        Last GTI Stop ..... 20183 10:35:11.560
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20183.43397577218  (days)      10:24:55:507  (h:m:s:ms)
#  Expected Stop .... 20183.44110601759  (days)      10:35:11:560  (h:m:s:ms)
#
#  Default Epoch is:  20183.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..             62.86
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.              4024
#
#  Default Newbins per Interval are:        4024
#  (giving       1 Interval of         4024 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with         4024 Newbins of      0.153125     (s)
#  Default resolution is 0.7793240557E-01
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
#   Chisq. vs. period ready
#
#  Period :   9.791    dP/dt :   0.000
#  Intv    1   Start 20183 10:24:55
#      Ser.1     Avg  188.4        Chisq  1509.       Var  460.2     Newbs.     64
#                Min  135.5          Max  231.5    expVar  19.57      Bins 116155
# Writing output file: ./reduced_output/6050390268/efsearch_output/testing_efsearc
# 100% completed
# Interval 2 rejected; all bins zero
#
#  Period :   9.791    dP/dt :   0.000
#  Intv    3   Start     0  0: 0: 0
#      Ser.1     Avg  0.000        Chisq  0.000       Var  0.000     Newbs.      0
#                Min 0.1000E+35      Max-0.1000E+35expVar  0.000      Bins     -1
#
# Frame ready : Writing in output : ./reduced_output/6050390268/efsearch_output/te
# Processed ./reduced_output/6050390268/ni6050390268_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9
+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20119 00:19:54.793
#  No. of Rows .......           10        Last GTI Stop ..... 20119 17:29:58.129
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20119.01382862175  (days)       0:19:54:793  (h:m:s:ms)
#  Expected Stop .... 20119.72914500965  (days)      17:29:58:129  (h:m:s:ms)
#
#  Default Epoch is:  20119.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6306.46
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            403614
#
#  Default Newbins per Interval are:      403614
#  (giving       1 Interval of       403614 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       403614 Newbins of      0.153125     (s)
#  Default resolution is 0.7769799858E-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
#   Chisq. vs. period ready
#
#  Period :   9.800    dP/dt :   0.000
#  Intv    1   Start 20119  0:19:54
#      Ser.1     Avg  1007.        Chisq 0.9095E+05   Var 0.1780E+05 Newbs.     64
#                Min  846.2          Max  1212.    expVar  12.53      Bins5179327
# Writing output file: ./reduced_output/6050390234/efsearch_output/testing_efsearc
# 100% completed
# Interval 2 rejected; all bins zero
#
#  Period :   9.800    dP/dt :   0.000
#  Intv    3   Start     0  0: 0: 0
#      Ser.1     Avg  0.000        Chisq  0.000       Var  0.000     Newbs.      0
#                Min 0.1000E+35      Max-0.1000E+35expVar  0.000      Bins     -1
#
# Frame ready : Writing in output : ./reduced_output/6050390234/efsearch_output/te
# Processed ./reduced_output/6050390234/ni6050390234_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.800300000000002, Chi-square: 90951.2734375, TSTARTI: 20119
# Processing obsID: 6050390238
# Processing light curve: ./reduced_output/6050390238/ni6050390238_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390238/ni6050390238_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20123 00:18:56.361
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20123 17:27:59.941
#  No. of Rows .......      4402463        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09184600E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14319800E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20123 00:18:56.361
#  No. of Rows .......            9        Last GTI Stop ..... 20123 17:27:59.941
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20123.01315232879  (days)       0:18:56:361  (h:m:s:ms)
#  Expected Stop .... 20123.72777709226  (days)      17:27:59:941  (h:m:s:ms)
#
#  Default Epoch is:  20123.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6300.37
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            403224
#
#  Default Newbins per Interval are:      403224
#  (giving       1 Interval of       403224 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       403224 Newbins of      0.153125     (s)
#  Default resolution is 0.7777314842E-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
#   Chisq. vs. period ready
#
#  Period :   9.800    dP/dt :   0.000
#  Intv    1   Start 20123  0:18:56
#      Ser.1     Avg  1150.        Chisq 0.7749E+05   Var 0.2429E+05 Newbs.     64
#                Min  936.2          Max  1378.    expVar  20.08      Bins4213038
# Writing output file: ./reduced_output/6050390238/efsearch_output/testing_efsearc
# 100% completed
# Interval 2 rejected; all bins zero
#
#  Period :   9.800    dP/dt :   0.000
#  Intv    3   Start     0  0: 0: 0
#      Ser.1     Avg  0.000        Chisq  0.000       Var  0.000     Newbs.      0
#                Min 0.1000E+35      Max-0.1000E+35expVar  0.000      Bins     -1
#
# Frame ready : Writing in output : ./reduced_output/6050390238/efsearch_output/te
# Processed ./reduced_output/6050390238/ni6050390238_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.8, Chi-square: 77485.0625, TSTARTI: 20123
# Processing obsID: 6050390258
# Processing light curve: ./reduced_output/6050390258/ni6050390258_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390258/ni6050390258_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20171 04:06:17.523
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20171 22:48:18.323
#  No. of Rows .......      1296051        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09215200E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14320700E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20171 04:06:17.523
#  No. of Rows .......            4        Last GTI Stop ..... 20171 22:48:18.323
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20171.17103614542  (days)       4: 6:17:523  (h:m:s:ms)
#  Expected Stop .... 20171.95021206659  (days)      22:48:18:323  (h:m:s:ms)
#
#  Default Epoch is:  20171.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6869.47
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            439647
#
#  Default Newbins per Interval are:      439647
#  (giving       1 Interval of       439647 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       439647 Newbins of      0.153125     (s)
#  Default resolution is 0.7132995335E-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.793    dP/dt :   0.000
#  Intv    1   Start 20171  4: 6:17
#      Ser.1     Avg  627.6        Chisq 0.1988E+05   Var  6193.     Newbs.     64
#                Min  482.3          Max  753.2    expVar  19.94      Bins1296051
# Writing output file: ./reduced_output/6050390258/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390258/ni6050390258_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.7925, Chi-square: 19877.603515625, TSTARTI: 20171
# Processing obsID: 6050390241
# Processing light curve: ./reduced_output/6050390241/ni6050390241_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390241/ni6050390241_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20126 18:02:51.271
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20126 21:17:49.809
#  No. of Rows .......      1154636        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09176300E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14311300E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20126 18:02:51.271
#  No. of Rows .......            9        Last GTI Stop ..... 20126 21:17:49.809
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20126.75198230415  (days)      18: 2:51:271  (h:m:s:ms)
#  Expected Stop .... 20126.88738204793  (days)      21:17:49:809  (h:m:s:ms)
#
#  Default Epoch is:  20126.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           1193.73
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.             76399
#
#  Default Newbins per Interval are:       76399
#  (giving       1 Interval of        76399 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with        76399 Newbins of      0.153125     (s)
#  Default resolution is 0.4104765769E-02
#  Type INDEF to accept the default value
# ...
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390247/ni6050390247_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20140 07:28:44.805
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20140 16:54:47.722
#  No. of Rows .......      1734018        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09160300E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14304900E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20140 07:28:44.805
#  No. of Rows .......            2        Last GTI Stop ..... 20140 16:54:47.722
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20140.31162969103  (days)       7:28:44:805  (h:m:s:ms)
#  Expected Stop .... 20140.70471900067  (days)      16:54:47:722  (h:m:s:ms)
#
#  Default Epoch is:  20140.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           3465.60
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            221799
#
#  Default Newbins per Interval are:      221799
#  (giving       1 Interval of       221799 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       221799 Newbins of      0.153125     (s)
#  Default resolution is 0.1413892759E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.791    dP/dt :   0.000
#  Intv    1   Start 20140  7:28:44
#      Ser.1     Avg  1527.        Chisq 0.3085E+05   Var 0.4618E+05 Newbs.     64
#                Min  1218.          Max  1858.    expVar  95.62      Bins1734018
# Writing output file: ./reduced_output/6050390247/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390247/ni6050390247_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.790700000000001, Chi-square: 30848.111328125, TSTARTI: 20140
# Processing obsID: 6050390253
# Processing light curve: ./reduced_output/6050390253/ni6050390253_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390253/ni6050390253_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20146 12:15:14.170
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20146 18:29:49.534
#  No. of Rows .......      1417838        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09176600E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14292300E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20146 12:15:14.170
#  No. of Rows .......            4        Last GTI Stop ..... 20146 18:29:49.534
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20146.51058067432  (days)      12:15:14:170  (h:m:s:ms)
#  Expected Stop .... 20146.77071220250  (days)      18:29:49:534  (h:m:s:ms)
#
#  Default Epoch is:  20146.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           2293.40
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            146778
#
#  Default Newbins per Interval are:      146778
#  (giving       1 Interval of       146778 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       146778 Newbins of      0.153125     (s)
#  Default resolution is 0.2136559975E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
#   Chisq. vs. period ready
#
#  Period :   9.796    dP/dt :   0.000
#  Intv    1   Start 20146 12:15:14
#      Ser.1     Avg  1703.        Chisq 0.3960E+05   Var 0.8369E+05 Newbs.     64
#                Min  1217.          Max  2097.    expVar  135.1      Bins1374467
# Writing output file: ./reduced_output/6050390253/efsearch_output/testing_efsearc
# 100% completed
# Interval 2 rejected; all bins zero
#
#  Period :   9.796    dP/dt :   0.000
#  Intv    3   Start     0  0: 0: 0
#      Ser.1     Avg  0.000        Chisq  0.000       Var  0.000     Newbs.      0
#                Min 0.1000E+35      Max-0.1000E+35expVar  0.000      Bins     -1
#
# Frame ready : Writing in output : ./reduced_output/6050390253/efsearch_output/te
# Processed ./reduced_output/6050390253/ni6050390253_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.795800000000002, Chi-square: 39595.4296875, TSTARTI: 20146
# Processing obsID: 6050390229
# Processing light curve: ./reduced_output/6050390229/ni6050390229_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390229/ni6050390229_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20114 01:08:40.938
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20114 21:22:28.308
#  No. of Rows .......      1837287        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09187100E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14320000E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20114 01:08:40.938
#  No. of Rows .......            6        Last GTI Stop ..... 20114 21:22:28.308
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20114.04769603859  (days)       1: 8:40:938  (h:m:s:ms)
#  Expected Stop .... 20114.89060542001  (days)      21:22:28:308  (h:m:s:ms)
#
#  Default Epoch is:  20114.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           7431.36
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            475608
#
#  Default Newbins per Interval are:      475608
#  (giving       1 Interval of       475608 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       475608 Newbins of      0.153125     (s)
#  Default resolution is 0.6593665371E-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.749    dP/dt :   0.000
#  Intv    1   Start 20114  1: 8:41
#      Ser.1     Avg  977.6        Chisq 0.2693E+05   Var 0.1451E+05 Newbs.     64
#                Min  847.2          Max  1233.    expVar  34.56      Bins1837287
# Writing output file: ./reduced_output/6050390229/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390229/ni6050390229_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.7491, Chi-square: 26926.697265625, TSTARTI: 20114
# Processing obsID: 6050390246
# Processing light curve: ./reduced_output/6050390246/ni6050390246_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390246/ni6050390246_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20134 13:22:44.892
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20134 18:05:32.776
#  No. of Rows .......       802589        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09174000E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14319000E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20134 13:22:44.892
#  No. of Rows .......            2        Last GTI Stop ..... 20134 18:05:32.776
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20134.55746402211  (days)      13:22:44:892  (h:m:s:ms)
#  Expected Stop .... 20134.75385157562  (days)      18: 5:32:776  (h:m:s:ms)
#
#  Default Epoch is:  20134.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           1731.42
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            110811
#
#  Default Newbins per Interval are:      110811
#  (giving       1 Interval of       110811 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       110811 Newbins of      0.153125     (s)
#  Default resolution is 0.2830043949E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
# 100% completed
#   Chisq. vs. period ready
#
#  Period :   9.826    dP/dt :   0.000
#  Intv    1   Start 20134 13:22:44
#      Ser.1     Avg  1264.        Chisq 0.1311E+05   Var 0.3462E+05 Newbs.     64
#                Min  1003.          Max  1541.    expVar  168.3      Bins 802589
# Writing output file: ./reduced_output/6050390246/efsearch_output/testing_efsearc
# Processed ./reduced_output/6050390246/ni6050390246_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.826300000000002, Chi-square: 13110.7099609375, TSTARTI: 20134
# Processing obsID: 6050390269
# Processing light curve: ./reduced_output/6050390269/ni6050390269_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390269/ni6050390269_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20184 05:07:27.332
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20184 17:33:24.541
#  No. of Rows .......       103406        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09224900E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14309800E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20184 05:07:27.332
#  No. of Rows .......            2        Last GTI Stop ..... 20184 17:33:24.541
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20184.21351078479  (days)       5: 7:27:332  (h:m:s:ms)
#  Expected Stop .... 20184.73153404128  (days)      17:33:24:541  (h:m:s:ms)
#
#  Default Epoch is:  20184.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           4567.06
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            292292
#
#  Default Newbins per Interval are:      292292
#  (giving       1 Interval of       292292 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       292292 Newbins of      0.153125     (s)
#  Default resolution is 0.1072899703E-02
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
#   Chisq. vs. period ready
#
#  Period :   9.792    dP/dt :   0.000
#  Intv    1   Start 20184  5: 7:27
#      Ser.1     Avg  195.4        Chisq  1732.       Var  661.8     Newbs.     64
#                Min  137.1          Max  256.6    expVar  24.43      Bins  99981
# Writing output file: ./reduced_output/6050390269/efsearch_output/testing_efsearc
# 100% completed
# Interval 2 rejected; all bins zero
#
#  Period :   9.792    dP/dt :   0.000
#  Intv    3   Start     0  0: 0: 0
#      Ser.1     Avg  0.000        Chisq  0.000       Var  0.000     Newbs.      0
#                Min 0.1000E+35      Max-0.1000E+35expVar  0.000      Bins     -1
#
# Frame ready : Writing in output : ./reduced_output/6050390269/efsearch_output/te
# Processed ./reduced_output/6050390269/ni6050390269_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.792100000000001, Chi-square: 1732.2943115234375, TSTARTI: 20184
# Processing obsID: 6050390264
# Processing light curve: ./reduced_output/6050390264/ni6050390264_0mpu7_cl_night_barycorr_orbit.evt
#
# efsearch 1.1 (xronos6.0)
#
#  Series 1 file    1:./reduced_output/6050390264/ni6050390264_0mpu7_cl_night_bary
#
#  Selected FITS extensions: 1 - RATE TABLE; 3 - GTIs
#
#  Source ............ Swift_J0243.6+61    Start Time (d) .... 20177 04:14:23.651
#  FITS Extension ....  1 - `EVENTS    `   Stop Time (d) ..... 20177 22:55:43.491
#  No. of Rows .......       251167        Bin Time (s) ......   0.4000E-07
#  Right Ascension ... 4.09199400E+01      Internal time sys.. Converted to TJD
#  Declination ....... 6.14319200E+01      Experiment ........ NICER    XTI
#
#  Corrections applied: Vignetting - No ; Deadtime - No ; Bkgd - No ; Clock - Yes
#
#  Selected Columns:  1- Time;  4- E-Channel;
#
#  File contains arrival-time data.
#
#  FITS Extension ....  3 - `GTI       `   First GTI Start ... 20177 04:14:23.651
#  No. of Rows .......            2        Last GTI Stop ..... 20177 22:55:43.491
#  Selected Columns:    1 - GTI Start;    2 - GTI Stop
#
#
#
#  Expected Start ... 20177.17666263002  (days)       4:14:23:651  (h:m:s:ms)
#  Expected Stop .... 20177.95536447690  (days)      22:55:43:491  (h:m:s:ms)
#
#  Default Epoch is:  20177.00000
# Type INDEF to accept the default value
#  Epoch format is days.
#  Period format is seconds.
#  Expected Cycles ..           6865.29
#  Default phase bins per period are:         8
#  Type INDEF to accept the default value
#
#  Newbin Time ......    0.15312500      (s)
#  Maximum Newbin No.            439379
#
#  Default Newbins per Interval are:      439379
#  (giving       1 Interval of       439379 Newbins)
#  Type INDEF to accept the default value
#
#  Maximum of       1 Intvs. with       439379 Newbins of      0.153125     (s)
#  Default resolution is 0.7137346118E-03
#  Type INDEF to accept the default value
#  Default number of periods is       128
#  Type INDEF to accept the default value
#
#     1024 analysis results per interval
#
#   Chisq. vs. period ready
#
#  Period :   9.794    dP/dt :   0.000
#  Intv    1   Start 20177  4:14:23
#      Ser.1     Avg  366.5        Chisq  4362.       Var  2755.     Newbs.     64
#                Min  258.5          Max  431.0    expVar  39.97      Bins 215071
# Writing output file: ./reduced_output/6050390264/efsearch_output/testing_efsearc
# 100% completed
# Interval 2 rejected; all bins zero
#
#  Period :   9.794    dP/dt :   0.000
#  Intv    3   Start     0  0: 0: 0
#      Ser.1     Avg  0.000        Chisq  0.000       Var  0.000     Newbs.      0
#                Min 0.1000E+35      Max-0.1000E+35expVar  0.000      Bins     -1
#
# Frame ready : Writing in output : ./reduced_output/6050390264/efsearch_output/te
# Processed ./reduced_output/6050390264/ni6050390264_0mpu7_cl_night_barycorr_orbit.evt, Best-fit period: 9.794, Chi-square: 4361.5830078125, TSTARTI: 20177
# All periods, chi-squares, and TSTARTI values saved to all_lc_periods_chisq_py_evt_files_bary_orbit.txt
