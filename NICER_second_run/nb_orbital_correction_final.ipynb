# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt
import os
import re

#Source code page: http://astro.uni-tuebingen.de/software/idl/aitlib/astro/binarycor.html
#Source code link: http://astro.uni-tuebingen.de/software/idl/aitlib/astro/binarycor.pro

# %%
def Binary_orbit(time,asini,porb,ecc,omega_d,t0=-1,t90=-1,pporb=0.0,limit=1.0*10**-10,maxiter=40):

	time=np.array(time)  #time should be an array to prevent round-off errors
	if t90==-1 and t0==-1:
		print("error: need t90 or t0 value")
		return

	if t90!=-1 and t0!=-1:
		print("error: Only one of the t90 and t0 arguments is allowed")
		return

	if ecc<0 :
		print("error: eccentricity must be positive!")
		return
	if ecc>=1:
		print("error: Orbit correction has only been implemented for circular and elliptic orbits")
		return
	if ecc==0:
		omega_d=0 #circular orbit
	print(t0)
	if t0 ==-1:
		t0 = t90+(omega_d-90.)/360. * porb
		print(t0,"Debugging time")
		
	if maxiter <=0:
		maxiter=20

	asini_d = asini/86400. #86400 seconds in a day, unit is light day
	t= time

	#Corrections for eccentricity 0<=ecc<1
	omega = omega_d * np.pi/180.0 # Radians conversion
	sinw = np.sin(omega)
	cosw = np.cos(omega)
	sq = ((1.-ecc)*(1.+ecc))**0.5
	cor =np.array([2.*limit]*len(t))
	

	#start with number of iterations = zero
	numiter=0
			
	contada=0
	print('starting iterations (max 20)')
	while((abs(np.amax(cor)) > limit) and (numiter < maxiter)):
		tper = (t-t0)/porb
		# print(tper)
		# Calculate the mean anomaly
		m = 2 * np.pi * (tper * (1. - 0.5 * pporb * tper))
		# print(m)
		# Normalize m to the range [0, 2π]
		m = m % (2 * np.pi)

		# Shift m to the range [-π, π] if needed
		m[m > np.pi] -= 2 * np.pi
		# print(m)
		m=np.array(m)

		print("Mean Anomaly:" ,m)
		
		eanom=np.array([1.0]*len(t))
		eanom = KeplerEquation1(m,ecc)  #use this command for a better solution
		
		# print("Eccentric Anomaly:", eanom)  # Debugging line

		sin_e = np.sin(eanom)
		cos_e = np.cos(eanom)
		# print("e: ",ecc,"a_sin_i",asini_d,"omega ",omega)
		# print("sinE: ",sin_e)
		# print("cosE: ",cos_e)
		z = asini_d*(sinw*(cos_e-ecc)+sq*cosw*sin_e) ##Romer Delay Term
		#print("correction factor(z): ",z*86400)
		f = (t-time)+z  
		# print("term f: ",f)                             
		df = (sq*cosw*cos_e - sinw*sin_e)*(2*np.pi*asini_d/(porb*(1.0-ecc*cos_e)))
		# print("term df:",df)
		cor =f/(1.0+df)
		# print("Final Correction: ",cor)
		t = t-cor #### Altering it to add this time 
		numiter=numiter+1
		contada=contada+1
		print('iteration ' + str(contada)+' completed (max 20)')
		if numiter >= maxiter:
			print("Exceeded maxiter iterations and did not reach convergence");
			break
	return(t)

# %%
def KeplerEquation1(m,ecc):
	m=np.array(m)
	if ecc<0 :
		print("error: eccentricity must be positive!")
		return
	if ecc>=1:
		print("error: Orbit correction has only been implemented for circular and elliptic orbits")
	
	#print("Mean anomaly input to kepler:", m)
	for j in range(0,len(m)):
		mod_m=m[j]/2/np.pi
		m[j]=m[j]-2*np.pi*round(mod_m)
		
		while m[j]>np.pi:
			m[j]=m[j]-2*np.pi
		while m[j]<-np.pi:
			m[j]=m[j]+2*np.pi
	if ecc==0:
		E=m
		
	aux=4.0*ecc+0.5
	alpha=(1.0-ecc)/aux
	
	Beta=m/(2.0*aux)
	aux=np.sqrt(Beta**2+alpha**3)
	
	z=Beta+aux
	test=np.array([1.0]*len(z))
	for j in range(0,len(m)):
		if z[j]<=0.0:
			z[j]=Beta[j]-aux[j]
			
		test[j]=abs(z[j])**(1/3)
	z=test
	for j in range(0,len(m)):
		if z[j]<0.0:
			z[j]=-z[j]
	s0=z-alpha/z
	
	s1=s0-(0.078*s0**5)/(1.0+ecc)
	e0=m+ecc*(3.0*s1-4.0*s1**3)	
	
	se0=np.sin(e0)
	ce0=np.cos(e0)
	
	##Newton Raphson method
	f  = e0-ecc*se0-m
	f1 = 1.0-ecc*ce0
	f2 = ecc*se0
	f3 = ecc*ce0
	f4 = -f2
	u1 = -f/f1
	u2 = -f/(f1+0.50*f2*u1)
	u3 = -f/(f1+0.50*f2*u2+.16666666666667*f3*u2*u2)
	u4 = -f/(f1+0.50*f2*u3+.16666666666667*f3*u3*u3+.041666666666667*f4*u3**3)
	
	eccanom=e0+u4
	
	for j in range(0,len(m)):
		while eccanom[j]>=2.0*np.pi:
			eccanom[j]=eccanom[j]-2.0*np.pi
		while eccanom[j]<2.0*np.pi:
			eccanom[j]=eccanom[j]+2.0*np.pi
	##better solution
	#print("ecc anomaly before iteration inside kepler equation :", eccanom)

	CONT=True
	thresh=10**-3
	for j in range(0,len(m)):
		if m[j]<0:
			m[j]=m[j]+2.0*np.pi
	diff=eccanom-np.sin(eccanom)-m
	for j in range(0,len(m)):
		if abs(diff[j])>10**-10:
			I=diff[j]
			while CONT==True:
				fe=eccanom[j]-ecc*np.sin(eccanom[j])-m[j]
				fs=1.0-ecc*np.cos(eccanom[j])
				oldval=eccanom[j]
				eccanom[j]=oldval-fe/fs
				if abs(oldval-eccanom[j])<thresh :CONT=False
			while eccanom[j]>= np.pi:eccanom[j]=eccanom[j]-2.0*np.pi
			while eccanom[j]< np.pi:eccanom[j]=eccanom[j]+2.0*np.pi

	# Iterate until convergence for each m value
	thresh = 1e-6  # Convergence threshold
	for j in range(len(m)):
        # Iterative correction (Newton-Raphson method)
		max_iter = 40  # Maximum number of iterations for each eccentric anomaly
		iter_count = 0
		
		while iter_count < max_iter:
            # Calculate the difference (Kepler's equation)
			fe = eccanom[j] - ecc * np.sin(eccanom[j]) - m[j]
			fs = 1.0 - ecc * np.cos(eccanom[j])

			# If fs is too small, break out to avoid division by zero
			if abs(fs) < 1e-10:
				break

			# Update the Eccentric Anomaly using Newton-Raphson
			new_eccanom = eccanom[j] - fe / fs

			# Check for convergence
			if abs(new_eccanom - eccanom[j]) < thresh:
				eccanom[j] = new_eccanom
				break
			eccanom[j] = new_eccanom
			iter_count += 1

        # If maximum iterations are exceeded, print a warning
		if iter_count >= max_iter:
			print(f"Warning: Did not converge for m[{j}] after {max_iter} iterations.")

		# Ensure the final value is within [-pi, pi]
		while eccanom[j] >= np.pi:
			eccanom[j] -= 2 * np.pi
		while eccanom[j] < -np.pi:
			eccanom[j] += 2 * np.pi
	return eccanom

# %%
## Function to find event files/lc files from the directory 
def find_event_files(base_directory):
    event_files = []
    
    # Regular expression to match the pattern ObsID/xti/event_cl/
    obsid_pattern = re.compile(r'^\d{10}$')
    #obsid_pattern = re.compile(r'^\d{10}/xti/event_cl/$')
    #For one file
    #obsid_pattern = re.compile(r'6050390244')
    
    # Regular expressions to match the specific filename patterns
    file_pattern = re.compile(r'^ni\d{10}_0mpu7_cl_(night|day)_barycorr.evt$')
    #file_pattern = re.compile(r'^ni\d{10}_cl_(night|day)mpu7_sr_night_barycorr.lc$')

    
    # List and sort the subdirectories numerically by ObsID
    obsid_dirs = [d for d in os.listdir(base_directory) if obsid_pattern.match(d)]
    obsid_dirs = sorted(obsid_dirs)

    for obsid_dir in obsid_dirs:
        obsid_path = os.path.join(base_directory, obsid_dir)

        # Check if it's a directory and matches the 10-digit ObsID pattern
        if os.path.isdir(obsid_path) and obsid_pattern.match(obsid_dir):
            #print(f"Found 10-digit ObsID folder: {obsid_dir}")

            # Look for files in this directory matching the .evt pattern
            for file in os.listdir(obsid_path):
                if file_pattern.match(file):
                    full_path = os.path.join(obsid_path, file)
                    event_files.append(full_path)
                    # print(f"Found .evt file: {full_path}")
    # ✅ Finally, sort event_files too, if needed
    event_files = sorted(event_files)

    return event_files

# %%
# Method to write corrected FITS file
def write_corrected_fits(original_fits, corrected_timestamps, corrected_gti_dict):
    import numpy as np
    base_name = os.path.basename(original_fits)
    original_dir = os.path.dirname(original_fits)
    new_file = os.path.join(original_dir, base_name.replace('.evt', '_orbit_gti.evt'))

    try:
        with fits.open(original_fits, mode='readonly') as hdul:
            MJDREFI = hdul[1].header['MJDREFI']
            MJDREFF = hdul[1].header['MJDREFF']
            TIMEZERO = hdul[1].header['TIMEZERO']
            MJDREF = MJDREFI + MJDREFF

            # Convert corrected MJD to MET
            corrected_met = (corrected_timestamps - MJDREF) * 86400 - TIMEZERO
            hdul[1].data['TIME'] = corrected_met

            # --- Apply GTI corrections ---
            for hdu_index, (corr_start, corr_stop) in corrected_gti_dict.items():
                start_met = (corr_start - MJDREF) * 86400 - TIMEZERO
                stop_met = (corr_stop - MJDREF) * 86400 - TIMEZERO

                # Replace in-place
                hdul[hdu_index].data['START'] = start_met.astype(np.float32)
                hdul[hdu_index].data['STOP'] = stop_met.astype(np.float32)

            # Save the new file
            hdul.writeto(new_file, overwrite=True)

        print(f"Corrected FITS file saved as {new_file}")
    
    except Exception as e:
        print(f"Error saving corrected FITS file: {str(e)}")

# %%
# Main function to process event files and save corrected fits files
def process_event_files(base_directory, asini, porb, ecc, omega_d, t0, t90):
    event_files = find_event_files(base_directory)
    
    all_input_times = []
    all_corrected_times = []

    for event_file in event_files:
        with fits.open(event_file) as evt:
            met = evt[1].data['TIME']  # Use this when BARYTIME=False
            if len(met) == 0:
                print(f"Skipping file {event_file}: No time values found.")
                continue

            times = ((met + evt[1].header['TIMEZERO']) / 86400) + \
                    evt[1].header['MJDREFI'] + evt[1].header['MJDREFF']
            all_input_times.append(times)

            corrected_times = Binary_orbit(times, asini, porb, ecc, omega_d, t0=t0, t90=t90)
            all_corrected_times.append(corrected_times)

            print("Romer Delay: ", (times - corrected_times))

            # --- Read and correct GTI HDUs ---
            corrected_gti_dict = {}  # {hdu_index: (corr_start, corr_stop)}
            for i in range(3, len(evt)):
                hdu = evt[i]
                if 'START' in hdu.columns.names and 'STOP' in hdu.columns.names:
                    start = hdu.data['START']
                    stop = hdu.data['STOP']
                    if len(start) == 0 or len(stop) == 0:
                        print(f"Skipping empty GTI HDU {i} in file {event_file}")
                        continue

                    timezero = evt[1].header['TIMEZERO']
                    mjdref = evt[1].header['MJDREFI'] + evt[1].header['MJDREFF']

                    start_mjd = ((start + timezero) / 86400.0) + mjdref
                    stop_mjd = ((stop + timezero) / 86400.0) + mjdref

                    corrected_start = Binary_orbit(start_mjd, asini, porb, ecc, omega_d, t0=t0, t90=t90)
                    corrected_stop = Binary_orbit(stop_mjd, asini, porb, ecc, omega_d, t0=t0, t90=t90)

                    corrected_gti_dict[i] = (corrected_start, corrected_stop)
            # Save the corrected FITS file
            write_corrected_fits(event_file, corrected_times, corrected_gti_dict)
    
    return all_input_times, all_corrected_times

# %%
############
# Input parameters taken from: 
# https://gammaray.nsstc.nasa.gov/gbm/science/pulsars/lightcurves/swiftj0243.html
############

base_directory = "./reduced_output" #Change the data accordingly\
asini = 115.531  # in light-seconds
porb = 27.6943  # in days
ecc = 0.1029
omega_d = -74.05
t0=-1
t90 = 58116.097  # Modified Julian Date

# Run the processing
input_times, corrected_times=process_event_files(base_directory, asini, porb, ecc, omega_d,t0=t0, t90=t90)
# Out:
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.88708506 -2.88708506 -2.88708504 ... -2.7985769  -2.7985769
#  -2.7985769 ]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.88738008 -2.88738008 -2.88738007 ... -2.7988592  -2.7988592
#  -2.7988592 ]
# iteration 2 completed (max 20)
# Romer Delay:  [0.00130036 0.00130036 0.00130036 ... 0.00124429 0.00124429 0.00124429]
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.88708506 -2.87243743 -2.85783444 -2.84318156 -2.82858645 -2.81392831
#  -2.79928067]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.88738008 -2.87273047 -2.85812545 -2.84347048 -2.82887325 -2.81421294
#  -2.79956308]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.88642068 -2.87177567 -2.85714642 -2.84249617 -2.82785116 -2.81320877
#  -2.79857689]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.88671561 -2.87206862 -2.85743733 -2.84278499 -2.82813785 -2.8134933
#  -2.7988592 ]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.87243743 -2.85783444 -2.82858645 -2.79928067]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.87273047 -2.85812545 -2.82887325 -2.79956308]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.87177567 -2.85714642 -2.82785116 -2.79857689]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.87206862 -2.85743733 -2.82813785 -2.7988592 ]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.88708506 -2.87243743 -2.85783444 -2.84318156 -2.82858645 -2.81392831
#  -2.79928067]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.88738008 -2.87273047 -2.85812545 -2.84347048 -2.82887325 -2.81421294
#  -2.79956308]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.88642068 -2.87177567 -2.85714642 -2.84249617 -2.82785116 -2.81320877
#  -2.79857689]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.88671561 -2.87206862 -2.85743733 -2.84278499 -2.82813785 -2.8134933
#  -2.7988592 ]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.87243743 -2.85783444 -2.82858645 -2.79928067]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.87273047 -2.85812545 -2.82887325 -2.79956308]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.87177567 -2.85714642 -2.82785116 -2.79857689]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.87206862 -2.85743733 -2.82813785 -2.7988592 ]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.88708506 -2.87243743 -2.85783444 -2.84318156 -2.82858645 -2.81392831
#  -2.79928067]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.88738008 -2.87273047 -2.85812545 -2.84347048 -2.82887325 -2.81421294
#  -2.79956308]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.88642068 -2.87177567 -2.85714642 -2.84249617 -2.82785116 -2.81320877
#  -2.79857689]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.88671561 -2.87206862 -2.85743733 -2.84278499 -2.82813785 -2.8134933
#  -2.7988592 ]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.88708506 -2.87243743 -2.85783444 -2.84318156 -2.82858645 -2.81392831
#  -2.79928067]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.88738008 -2.87273047 -2.85812545 -2.84347048 -2.82887325 -2.81421294
#  -2.79956308]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.88642068 -2.87177567 -2.85714642 -2.84249617 -2.82785116 -2.81320877
#  -2.79857689]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.88671561 -2.87206862 -2.85743733 -2.84278499 -2.82813785 -2.8134933
#  -2.7988592 ]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.87243743 -2.85783444 -2.82858645 -2.79928067]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.87273047 -2.85812545 -2.82887325 -2.79956308]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.87177567 -2.85714642 -2.82785116 -2.79857689]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.87206862 -2.85743733 -2.82813785 -2.7988592 ]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.88708506 -2.87243743 -2.85783444 -2.84318156 -2.82858645 -2.81392831
#  -2.79928067]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.88738008 -2.87273047 -2.85812545 -2.84347048 -2.82887325 -2.81421294
#  -2.79956308]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.88642068 -2.87177567 -2.85714642 -2.84249617 -2.82785116 -2.81320877
#  -2.79857689]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.88671561 -2.87206862 -2.85743733 -2.84278499 -2.82813785 -2.8134933
#  -2.7988592 ]
# iteration 2 completed (max 20)
# Corrected FITS file saved as ./reduced_output/6050390227/ni6050390227_0mpu7_cl_night_barycorr_orbit_gti.evt
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59445    -2.59444999 -2.59444999 ... -2.53501907 -2.53501907
#  -2.53501906]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59469672 -2.59469671 -2.59469671 ... -2.53525389 -2.53525389
#  -2.53525389]
# iteration 2 completed (max 20)
# Romer Delay:  [0.00108745 0.00108745 0.00108745 ... 0.00103502 0.00103502 0.00103502]
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59445    -2.57979973 -2.5651442  -2.55054381 -2.5358909 ]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59469672 -2.58004357 -2.56538513 -2.5507818  -2.53612591]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59359129 -2.57895677 -2.56431962 -2.54966146 -2.53501906]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59383784 -2.57920045 -2.56456039 -2.54989928 -2.53525388]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59445   -2.5358909]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59469672 -2.53612591]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59359917 -2.53501906]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59384572 -2.53525388]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59445    -2.57979973 -2.5358909 ]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59469672 -2.58004357 -2.53612591]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59359129 -2.57895677 -2.53501906]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59383784 -2.57920045 -2.53525388]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59445    -2.57979973 -2.55054381 -2.5358909 ]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59469672 -2.58004357 -2.5507818  -2.53612591]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59359129 -2.57895677 -2.54966146 -2.53501906]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59383784 -2.57920045 -2.54989928 -2.53525388]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59445    -2.57979973 -2.5358909 ]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59469672 -2.58004357 -2.53612591]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59359129 -2.57895677 -2.53501906]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59383784 -2.57920045 -2.53525388]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59445    -2.57979973 -2.5651442  -2.55054381 -2.5358909 ]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59469672 -2.58004357 -2.56538513 -2.5507818  -2.53612591]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59359129 -2.57895677 -2.56431962 -2.54966146 -2.53501906]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59383784 -2.57920045 -2.56456039 -2.54989928 -2.53525388]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59445    -2.5651442  -2.55054381 -2.5358909 ]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59469672 -2.56538513 -2.5507818  -2.53612591]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59359917 -2.56431962 -2.54966146 -2.53501906]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59384572 -2.56456039 -2.54989928 -2.53525388]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59445    -2.57979973 -2.55054381 -2.5358909 ]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59469672 -2.58004357 -2.5507818  -2.53612591]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59359129 -2.57895677 -2.54966146 -2.53501906]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59383784 -2.57920045 -2.54989928 -2.53525388]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59445    -2.57979973 -2.5651442  -2.55054381 -2.5358909 ]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59469672 -2.58004357 -2.56538513 -2.5507818  -2.53612591]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59359129 -2.57895677 -2.56431962 -2.54966146 -2.53501906]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59383784 -2.57920045 -2.56456039 -2.54989928 -2.53525388]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59445    -2.57979973 -2.5651442  -2.5358909 ]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59469672 -2.58004357 -2.56538513 -2.53612591]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59359129 -2.57895677 -2.56431962 -2.53501906]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59383784 -2.57920045 -2.56456039 -2.53525388]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59445    -2.57979973 -2.55054381 -2.5358909 ]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59469672 -2.58004357 -2.5507818  -2.53612591]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.59359129 -2.57895677 -2.54966146 -2.53501906]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.59383784 -2.57920045 -2.54989928 -2.53525388]
# iteration 2 completed (max 20)
# Corrected FITS file saved as ./reduced_output/6050390228/ni6050390228_0mpu7_cl_night_barycorr_orbit_gti.evt
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52129314 -2.52129313 -2.52129312 ... -2.33005683 -2.33005683
#  -2.33005683]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52152512 -2.52152512 -2.5215251  ... -2.33024586 -2.33024586
#  -2.33024586]
# iteration 2 completed (max 20)
# Romer Delay:  [0.0010225  0.0010225  0.0010225  ... 0.00083321 0.00083321 0.00083321]
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52129314 -2.38957449 -2.37490319 -2.36031329 -2.34567088 -2.33105997]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52152512 -2.38977754 -2.37510283 -2.36050952 -2.34586364 -2.33124925]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52037928 -2.38862649 -2.37399458 -2.35933904 -2.34469662 -2.33005683]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52061107 -2.38882932 -2.37419401 -2.35953503 -2.34488915 -2.33024586]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52129314 -2.36031329 -2.35935357 -2.35935334 -2.35935323 -2.35935313
#  -2.35935294 -2.3593528  -2.35935266 -2.35935252 -2.35935241 -2.35935228
#  -2.35935218 -2.35935205 -2.35935195 -2.35935185 -2.35935171 -2.35935162
#  -2.35935152 -2.35935142 -2.35935133 -2.35935124 -2.35935115 -2.35935105
#  -2.35935096 -2.3593509  -2.35935081 -2.35935075 -2.35935064 -2.35935059
#  -2.35935053 -2.35935045 -2.35935036 -2.35935028 -2.3593502  -2.35935012
#  -2.35935001 -2.35934993 -2.35934985 -2.35934978 -2.35934968 -2.35934963
#  -2.35934955 -2.35934948 -2.3593494  -2.35934927 -2.35934917 -2.35934904
#  -2.35934894 -2.35934881 -2.35934871 -2.35934858 -2.35934847 -2.35934834
#  -2.35934824 -2.35934814 -2.35934807 -2.35934796 -2.35934782 -2.35934765
#  -2.35934751 -2.35934736 -2.35934715 -2.35934701 -2.35934682 -2.35934663
#  -2.35934641 -2.35934622 -2.35934615 -2.35934591 -2.35934564 -2.35934531
#  -2.35934408 -2.34567088 -2.33105997]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52152512 -2.36050952 -2.35954958 -2.35954934 -2.35954924 -2.35954913
#  -2.35954894 -2.3595488  -2.35954866 -2.35954852 -2.35954842 -2.35954828
#  -2.35954818 -2.35954805 -2.35954795 -2.35954785 -2.35954772 -2.35954762
#  -2.35954753 -2.35954742 -2.35954733 -2.35954724 -2.35954715 -2.35954705
#  -2.35954696 -2.3595469  -2.35954681 -2.35954676 -2.35954664 -2.35954659
#  -2.35954653 -2.35954645 -2.35954636 -2.35954628 -2.3595462  -2.35954612
#  -2.35954601 -2.35954593 -2.35954585 -2.35954578 -2.35954568 -2.35954563
#  -2.35954556 -2.35954549 -2.3595454  -2.35954527 -2.35954517 -2.35954504
#  -2.35954494 -2.35954481 -2.35954471 -2.35954458 -2.35954448 -2.35954434
#  -2.35954424 -2.35954414 -2.35954407 -2.35954396 -2.35954382 -2.35954365
#  -2.35954351 -2.35954337 -2.35954315 -2.35954301 -2.35954282 -2.35954264
#  -2.35954241 -2.35954222 -2.35954215 -2.35954191 -2.35954164 -2.35954131
#  -2.35954008 -2.34586364 -2.33124925]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52038716 -2.35935361 -2.35935338 -2.35935327 -2.35935317 -2.35935298
#  -2.35935283 -2.35935269 -2.35935255 -2.35935245 -2.35935231 -2.35935221
#  -2.35935208 -2.35935198 -2.35935188 -2.35935175 -2.35935165 -2.35935156
#  -2.35935146 -2.35935136 -2.35935127 -2.35935118 -2.35935108 -2.35935099
#  -2.35935093 -2.35935084 -2.35935078 -2.35935067 -2.35935061 -2.35935056
#  -2.35935048 -2.35935039 -2.35935031 -2.35935023 -2.35935015 -2.35935003
#  -2.35934995 -2.35934988 -2.3593498  -2.3593497  -2.35934965 -2.35934958
#  -2.3593495  -2.35934943 -2.3593493  -2.3593492  -2.35934907 -2.35934897
#  -2.35934884 -2.35934874 -2.35934861 -2.35934851 -2.35934837 -2.35934827
#  -2.35934817 -2.3593481  -2.359348   -2.35934786 -2.35934768 -2.35934754
#  -2.3593474  -2.35934719 -2.35934704 -2.35934685 -2.35934667 -2.35934645
#  -2.35934626 -2.35934619 -2.35934595 -2.35934568 -2.35934535 -2.35934413
#  -2.35933904 -2.34469662 -2.33005683]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52061895 -2.35954961 -2.35954938 -2.35954927 -2.35954917 -2.35954898
#  -2.35954884 -2.35954869 -2.35954856 -2.35954845 -2.35954831 -2.35954822
#  -2.35954808 -2.35954798 -2.35954788 -2.35954775 -2.35954766 -2.35954756
#  -2.35954746 -2.35954737 -2.35954727 -2.35954718 -2.35954708 -2.35954699
#  -2.35954694 -2.35954684 -2.35954679 -2.35954667 -2.35954661 -2.35954656
#  -2.35954648 -2.35954639 -2.35954631 -2.35954623 -2.35954615 -2.35954604
#  -2.35954596 -2.35954588 -2.3595458  -2.3595457  -2.35954565 -2.35954558
#  -2.35954551 -2.35954543 -2.3595453  -2.3595452  -2.35954507 -2.35954497
#  -2.35954484 -2.35954474 -2.35954461 -2.35954451 -2.35954438 -2.35954427
#  -2.35954417 -2.3595441  -2.359544   -2.35954386 -2.35954369 -2.35954354
#  -2.3595434  -2.35954319 -2.35954304 -2.35954285 -2.35954267 -2.35954245
#  -2.35954226 -2.35954219 -2.35954195 -2.35954168 -2.35954135 -2.35954013
#  -2.35953503 -2.34488915 -2.33024586]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52129314 -2.38957449 -2.36031329 -2.3593508  -2.35935061 -2.35935041
#  -2.35935022 -2.35935008 -2.35934993 -2.35934975 -2.35934964 -2.35934951
#  -2.35934937 -2.35934923 -2.35934913 -2.35934903 -2.3593489  -2.3593488
#  -2.3593487  -2.35934861 -2.35934852 -2.35934842 -2.35934832 -2.35934823
#  -2.35934814 -2.35934805 -2.35934799 -2.35934793 -2.35934784 -2.35934775
#  -2.35934766 -2.35934757 -2.35934752 -2.35934743 -2.35934734 -2.35934726
#  -2.35934717 -2.35934709 -2.35934701 -2.3593469  -2.35934682 -2.35934674
#  -2.35934666 -2.35934661 -2.35934652 -2.35934645 -2.35934637 -2.35934628
#  -2.35934618 -2.3593461  -2.35934602 -2.35934589 -2.35934579 -2.35934566
#  -2.35934559 -2.3593455  -2.35934536 -2.35934526 -2.35934512 -2.35934505
#  -2.35934495 -2.35934482 -2.35934468 -2.35934454 -2.35934437 -2.35934422
#  -2.35934408 -2.35934393 -2.35934376 -2.35934361 -2.35934343 -2.35934325
#  -2.35934318 -2.3593431  -2.35934291 -2.35934269 -2.35934241 -2.35934214
#  -2.35934173 -2.35934132 -2.35934123 -2.3593405  -2.34567088 -2.33105997]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52152512 -2.38977754 -2.36050952 -2.3595468  -2.35954661 -2.35954642
#  -2.35954623 -2.35954608 -2.35954593 -2.35954575 -2.35954565 -2.35954551
#  -2.35954537 -2.35954523 -2.35954513 -2.35954503 -2.3595449  -2.3595448
#  -2.35954471 -2.35954461 -2.35954452 -2.35954442 -2.35954432 -2.35954423
#  -2.35954415 -2.35954405 -2.35954399 -2.35954393 -2.35954384 -2.35954375
#  -2.35954366 -2.35954357 -2.35954352 -2.35954343 -2.35954334 -2.35954326
#  -2.35954317 -2.35954309 -2.35954301 -2.3595429  -2.35954282 -2.35954275
#  -2.35954266 -2.35954261 -2.35954253 -2.35954245 -2.35954237 -2.35954229
#  -2.35954218 -2.35954211 -2.35954202 -2.35954189 -2.35954179 -2.35954166
#  -2.3595416  -2.3595415  -2.35954136 -2.35954126 -2.35954112 -2.35954106
#  -2.35954095 -2.35954082 -2.35954068 -2.35954054 -2.35954037 -2.35954022
#  -2.35954008 -2.35953993 -2.35953976 -2.35953961 -2.35953943 -2.35953925
#  -2.35953918 -2.3595391  -2.35953891 -2.35953869 -2.35953841 -2.35953814
#  -2.35953773 -2.35953732 -2.35953723 -2.3595365  -2.34586364 -2.33124925]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52037928 -2.38862649 -2.35935084 -2.35935065 -2.35935045 -2.35935026
#  -2.35935012 -2.35934997 -2.35934978 -2.35934968 -2.35934954 -2.3593494
#  -2.35934926 -2.35934916 -2.35934906 -2.35934893 -2.35934883 -2.35934874
#  -2.35934864 -2.35934855 -2.35934845 -2.35934835 -2.35934826 -2.35934817
#  -2.35934808 -2.35934802 -2.35934796 -2.35934787 -2.35934778 -2.35934768
#  -2.35934759 -2.35934754 -2.35934746 -2.35934737 -2.35934729 -2.3593472
#  -2.35934712 -2.35934703 -2.35934692 -2.35934685 -2.35934677 -2.35934669
#  -2.35934663 -2.35934655 -2.35934647 -2.35934639 -2.35934631 -2.35934621
#  -2.35934613 -2.35934605 -2.35934592 -2.35934582 -2.35934569 -2.35934563
#  -2.35934553 -2.35934539 -2.35934529 -2.35934516 -2.35934509 -2.35934499
#  -2.35934485 -2.35934472 -2.35934458 -2.3593444  -2.35934426 -2.35934411
#  -2.35934397 -2.35934379 -2.35934365 -2.35934347 -2.35934329 -2.35934321
#  -2.35934314 -2.35934295 -2.35934272 -2.35934245 -2.35934218 -2.35934177
#  -2.35934136 -2.35934127 -2.35934054 -2.35933904 -2.34469662 -2.33005683]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52061107 -2.38882932 -2.35954685 -2.35954665 -2.35954645 -2.35954626
#  -2.35954612 -2.35954597 -2.35954579 -2.35954568 -2.35954554 -2.3595454
#  -2.35954527 -2.35954516 -2.35954506 -2.35954493 -2.35954483 -2.35954474
#  -2.35954464 -2.35954455 -2.35954445 -2.35954436 -2.35954426 -2.35954417
#  -2.35954408 -2.35954402 -2.35954396 -2.35954387 -2.35954378 -2.35954368
#  -2.3595436  -2.35954354 -2.35954346 -2.35954337 -2.35954329 -2.3595432
#  -2.35954312 -2.35954303 -2.35954292 -2.35954285 -2.35954277 -2.35954269
#  -2.35954264 -2.35954255 -2.35954247 -2.35954239 -2.35954232 -2.35954221
#  -2.35954213 -2.35954205 -2.35954192 -2.35954182 -2.35954169 -2.35954163
#  -2.35954153 -2.35954139 -2.35954129 -2.35954116 -2.35954109 -2.35954099
#  -2.35954085 -2.35954072 -2.35954058 -2.3595404  -2.35954026 -2.35954011
#  -2.35953997 -2.35953979 -2.35953965 -2.35953947 -2.35953929 -2.35953921
#  -2.35953914 -2.35953895 -2.35953872 -2.35953845 -2.35953818 -2.35953777
#  -2.35953736 -2.35953727 -2.35953654 -2.35953503 -2.34488915 -2.33024586]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52129314 -2.38957449 -2.36031329 -2.3593565  -2.35935626 -2.35935607
#  -2.35935592 -2.35935578 -2.35935563 -2.35935549 -2.35935535 -2.35935521
#  -2.35935511 -2.35935497 -2.35935486 -2.35935473 -2.35935463 -2.35935453
#  -2.35935444 -2.35935435 -2.35935426 -2.35935417 -2.35935412 -2.35935403
#  -2.35935397 -2.35935389 -2.35935378 -2.3593537  -2.35935362 -2.35935354
#  -2.35935346 -2.35935338 -2.3593533  -2.35935322 -2.35935314 -2.35935304
#  -2.35935294 -2.35935286 -2.35935279 -2.35935266 -2.35935256 -2.35935243
#  -2.35935233 -2.3593522  -2.35935209 -2.35935196 -2.35935187 -2.35935173
#  -2.3593516  -2.3593515  -2.35935136 -2.3593513  -2.35935119 -2.35935105
#  -2.35935092 -2.35935085 -2.35935071 -2.35935056 -2.35935039 -2.3593502
#  -2.35935002 -2.3593498  -2.35934957 -2.35934945 -2.35934926 -2.35934898
#  -2.35934866 -2.35934829 -2.35934756 -2.35934734 -2.34567088 -2.33105997]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52152512 -2.38977754 -2.36050952 -2.3595525  -2.35955227 -2.35955207
#  -2.35955193 -2.35955178 -2.35955163 -2.35955149 -2.35955135 -2.35955121
#  -2.35955111 -2.35955097 -2.35955087 -2.35955073 -2.35955063 -2.35955053
#  -2.35955045 -2.35955035 -2.35955026 -2.35955017 -2.35955012 -2.35955003
#  -2.35954997 -2.35954989 -2.35954978 -2.3595497  -2.35954962 -2.35954954
#  -2.35954946 -2.35954938 -2.3595493  -2.35954922 -2.35954915 -2.35954904
#  -2.35954894 -2.35954886 -2.35954879 -2.35954866 -2.35954856 -2.35954843
#  -2.35954833 -2.3595482  -2.3595481  -2.35954797 -2.35954787 -2.35954773
#  -2.3595476  -2.3595475  -2.35954737 -2.3595473  -2.35954719 -2.35954706
#  -2.35954692 -2.35954685 -2.35954671 -2.35954657 -2.35954639 -2.35954621
#  -2.35954603 -2.3595458  -2.35954557 -2.35954545 -2.35954526 -2.35954498
#  -2.35954466 -2.35954429 -2.35954356 -2.35954334 -2.34586364 -2.33124925]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52037928 -2.38862649 -2.35935654 -2.3593563  -2.35935611 -2.35935596
#  -2.35935581 -2.35935567 -2.35935552 -2.35935538 -2.35935524 -2.35935514
#  -2.359355   -2.3593549  -2.35935476 -2.35935466 -2.35935456 -2.35935447
#  -2.35935438 -2.35935429 -2.3593542  -2.35935414 -2.35935406 -2.359354
#  -2.35935392 -2.35935381 -2.35935373 -2.35935365 -2.35935356 -2.35935348
#  -2.35935341 -2.35935333 -2.35935325 -2.35935317 -2.35935307 -2.35935299
#  -2.35935289 -2.35935281 -2.35935269 -2.35935259 -2.35935246 -2.35935237
#  -2.35935224 -2.35935213 -2.359352   -2.3593519  -2.35935177 -2.35935163
#  -2.35935153 -2.3593514  -2.35935133 -2.35935123 -2.35935109 -2.35935095
#  -2.35935088 -2.35935074 -2.3593506  -2.35935042 -2.35935024 -2.35935006
#  -2.35934984 -2.35934961 -2.35934948 -2.35934929 -2.35934902 -2.3593487
#  -2.35934833 -2.3593476  -2.35934738 -2.35933904 -2.34469662 -2.33005683]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52061107 -2.38882932 -2.35955254 -2.3595523  -2.35955212 -2.35955197
#  -2.35955181 -2.35955167 -2.35955153 -2.35955139 -2.35955124 -2.35955114
#  -2.359551   -2.3595509  -2.35955076 -2.35955066 -2.35955056 -2.35955047
#  -2.35955038 -2.3595503  -2.3595502  -2.35955014 -2.35955006 -2.35955
#  -2.35954992 -2.35954981 -2.35954973 -2.35954965 -2.35954957 -2.35954948
#  -2.35954941 -2.35954933 -2.35954925 -2.35954917 -2.35954907 -2.35954899
#  -2.35954889 -2.35954882 -2.35954869 -2.3595486  -2.35954847 -2.35954837
#  -2.35954824 -2.35954813 -2.359548   -2.3595479  -2.35954777 -2.35954764
#  -2.35954753 -2.3595474  -2.35954733 -2.35954723 -2.35954709 -2.35954696
#  -2.35954689 -2.35954675 -2.3595466  -2.35954642 -2.35954624 -2.35954606
#  -2.35954584 -2.35954561 -2.35954549 -2.35954529 -2.35954502 -2.3595447
#  -2.35954433 -2.35954361 -2.35954338 -2.35953503 -2.34488915 -2.33024586]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52129314 -2.38957449 -2.36031329 -2.35935357 -2.35935334 -2.35935323
#  -2.35935313 -2.35935294 -2.3593528  -2.35935266 -2.35935252 -2.35935241
#  -2.35935228 -2.35935218 -2.35935205 -2.35935195 -2.35935185 -2.35935171
#  -2.35935162 -2.35935152 -2.35935142 -2.35935133 -2.35935124 -2.35935115
#  -2.35935105 -2.35935096 -2.3593509  -2.35935081 -2.35935075 -2.35935064
#  -2.35935059 -2.35935053 -2.35935045 -2.35935036 -2.35935028 -2.3593502
#  -2.35935012 -2.35935001 -2.35934993 -2.35934985 -2.35934978 -2.35934968
#  -2.35934963 -2.35934955 -2.35934948 -2.3593494  -2.35934927 -2.35934917
#  -2.35934904 -2.35934894 -2.35934881 -2.35934871 -2.35934858 -2.35934847
#  -2.35934834 -2.35934824 -2.35934814 -2.35934807 -2.35934796 -2.35934782
#  -2.35934765 -2.35934751 -2.35934736 -2.35934715 -2.35934701 -2.35934682
#  -2.35934663 -2.35934641 -2.35934622 -2.35934615 -2.35934591 -2.35934564
#  -2.35934531 -2.35934408 -2.34567088 -2.33105997]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52152512 -2.38977754 -2.36050952 -2.35954958 -2.35954934 -2.35954924
#  -2.35954913 -2.35954894 -2.3595488  -2.35954866 -2.35954852 -2.35954842
#  -2.35954828 -2.35954818 -2.35954805 -2.35954795 -2.35954785 -2.35954772
#  -2.35954762 -2.35954753 -2.35954742 -2.35954733 -2.35954724 -2.35954715
#  -2.35954705 -2.35954696 -2.3595469  -2.35954681 -2.35954676 -2.35954664
#  -2.35954659 -2.35954653 -2.35954645 -2.35954636 -2.35954628 -2.3595462
#  -2.35954612 -2.35954601 -2.35954593 -2.35954585 -2.35954578 -2.35954568
#  -2.35954563 -2.35954556 -2.35954549 -2.3595454  -2.35954527 -2.35954517
#  -2.35954504 -2.35954494 -2.35954481 -2.35954471 -2.35954458 -2.35954448
#  -2.35954434 -2.35954424 -2.35954414 -2.35954407 -2.35954396 -2.35954382
#  -2.35954365 -2.35954351 -2.35954337 -2.35954315 -2.35954301 -2.35954282
#  -2.35954264 -2.35954241 -2.35954222 -2.35954215 -2.35954191 -2.35954164
#  -2.35954131 -2.35954008 -2.34586364 -2.33124925]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52037928 -2.38862649 -2.35935361 -2.35935338 -2.35935327 -2.35935317
#  -2.35935298 -2.35935283 -2.35935269 -2.35935255 -2.35935245 -2.35935231
#  -2.35935221 -2.35935208 -2.35935198 -2.35935188 -2.35935175 -2.35935165
#  -2.35935156 -2.35935146 -2.35935136 -2.35935127 -2.35935118 -2.35935108
#  -2.35935099 -2.35935093 -2.35935084 -2.35935078 -2.35935067 -2.35935061
#  -2.35935056 -2.35935048 -2.35935039 -2.35935031 -2.35935023 -2.35935015
#  -2.35935003 -2.35934995 -2.35934988 -2.3593498  -2.3593497  -2.35934965
#  -2.35934958 -2.3593495  -2.35934943 -2.3593493  -2.3593492  -2.35934907
#  -2.35934897 -2.35934884 -2.35934874 -2.35934861 -2.35934851 -2.35934837
#  -2.35934827 -2.35934817 -2.3593481  -2.359348   -2.35934786 -2.35934768
#  -2.35934754 -2.3593474  -2.35934719 -2.35934704 -2.35934685 -2.35934667
#  -2.35934645 -2.35934626 -2.35934619 -2.35934595 -2.35934568 -2.35934535
#  -2.35934413 -2.35933904 -2.34469662 -2.33005683]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52061107 -2.38882932 -2.35954961 -2.35954938 -2.35954927 -2.35954917
#  -2.35954898 -2.35954884 -2.35954869 -2.35954856 -2.35954845 -2.35954831
#  -2.35954822 -2.35954808 -2.35954798 -2.35954788 -2.35954775 -2.35954766
#  -2.35954756 -2.35954746 -2.35954737 -2.35954727 -2.35954718 -2.35954708
#  -2.35954699 -2.35954694 -2.35954684 -2.35954679 -2.35954667 -2.35954661
#  -2.35954656 -2.35954648 -2.35954639 -2.35954631 -2.35954623 -2.35954615
#  -2.35954604 -2.35954596 -2.35954588 -2.3595458  -2.3595457  -2.35954565
#  -2.35954558 -2.35954551 -2.35954543 -2.3595453  -2.3595452  -2.35954507
#  -2.35954497 -2.35954484 -2.35954474 -2.35954461 -2.35954451 -2.35954438
#  -2.35954427 -2.35954417 -2.3595441  -2.359544   -2.35954386 -2.35954369
#  -2.35954354 -2.3595434  -2.35954319 -2.35954304 -2.35954285 -2.35954267
#  -2.35954245 -2.35954226 -2.35954219 -2.35954195 -2.35954168 -2.35954135
#  -2.35954013 -2.35953503 -2.34488915 -2.33024586]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52129314 -2.38957449 -2.36031329 -2.35935462 -2.35935443 -2.35935429
#  -2.35935415 -2.359354   -2.35935387 -2.35935373 -2.35935362 -2.35935353
#  -2.3593534  -2.3593533  -2.35935323 -2.35935313 -2.35935304 -2.35935295
#  -2.35935285 -2.35935275 -2.35935266 -2.35935257 -2.35935248 -2.35935238
#  -2.35935229 -2.35935223 -2.35935214 -2.35935209 -2.359352   -2.35935191
#  -2.35935183 -2.35935174 -2.35935165 -2.35935157 -2.35935149 -2.3593514
#  -2.35935129 -2.35935121 -2.35935113 -2.35935104 -2.35935096 -2.35935086
#  -2.35935081 -2.3593507  -2.35935062 -2.35935054 -2.35935044 -2.35935035
#  -2.35935025 -2.35935013 -2.35935003 -2.3593499  -2.35934976 -2.35934963
#  -2.35934952 -2.35934939 -2.35934925 -2.35934908 -2.35934894 -2.3593488
#  -2.35934866 -2.35934852 -2.35934834 -2.35934823 -2.35934806 -2.35934787
#  -2.35934768 -2.3593475  -2.35934724 -2.35934697 -2.35934673 -2.35934637
#  -2.35934588 -2.35934513 -2.34567088 -2.33105997]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52152512 -2.38977754 -2.36050952 -2.35955062 -2.35955044 -2.35955029
#  -2.35955015 -2.35955001 -2.35954987 -2.35954973 -2.35954963 -2.35954953
#  -2.3595494  -2.3595493  -2.35954923 -2.35954914 -2.35954904 -2.35954895
#  -2.35954885 -2.35954876 -2.35954866 -2.35954857 -2.35954848 -2.35954838
#  -2.3595483  -2.35954823 -2.35954815 -2.35954809 -2.359548   -2.35954792
#  -2.35954783 -2.35954774 -2.35954766 -2.35954757 -2.35954749 -2.3595474
#  -2.35954729 -2.35954721 -2.35954713 -2.35954705 -2.35954697 -2.35954686
#  -2.35954681 -2.3595467  -2.35954662 -2.35954654 -2.35954645 -2.35954635
#  -2.35954626 -2.35954613 -2.35954603 -2.3595459  -2.35954576 -2.35954563
#  -2.35954552 -2.35954539 -2.35954525 -2.35954508 -2.35954494 -2.3595448
#  -2.35954466 -2.35954452 -2.35954434 -2.35954424 -2.35954406 -2.35954387
#  -2.35954369 -2.3595435  -2.35954324 -2.35954297 -2.35954273 -2.35954237
#  -2.35954188 -2.35954113 -2.34586364 -2.33124925]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52037928 -2.38862649 -2.35935466 -2.35935447 -2.35935432 -2.35935418
#  -2.35935404 -2.3593539  -2.35935376 -2.35935366 -2.35935356 -2.35935343
#  -2.35935333 -2.35935326 -2.35935317 -2.35935307 -2.35935298 -2.35935288
#  -2.35935279 -2.35935269 -2.3593526  -2.35935251 -2.35935241 -2.35935232
#  -2.35935226 -2.35935217 -2.35935212 -2.35935203 -2.35935194 -2.35935186
#  -2.35935177 -2.35935168 -2.3593516  -2.35935152 -2.35935143 -2.35935132
#  -2.35935124 -2.35935115 -2.35935107 -2.35935099 -2.35935089 -2.35935083
#  -2.35935076 -2.35935065 -2.35935057 -2.35935047 -2.35935038 -2.35935029
#  -2.35935016 -2.35935006 -2.35934993 -2.3593498  -2.35934966 -2.35934956
#  -2.35934942 -2.35934928 -2.35934915 -2.35934897 -2.35934884 -2.3593487
#  -2.35934855 -2.35934838 -2.35934827 -2.35934809 -2.35934791 -2.35934772
#  -2.35934754 -2.35934732 -2.35934701 -2.35934677 -2.35934642 -2.35934592
#  -2.35934518 -2.35933904 -2.34469662 -2.33005683]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52061107 -2.38882932 -2.35955066 -2.35955047 -2.35955033 -2.35955018
#  -2.35955005 -2.3595499  -2.35954977 -2.35954966 -2.35954956 -2.35954943
#  -2.35954933 -2.35954926 -2.35954917 -2.35954907 -2.35954898 -2.35954889
#  -2.35954879 -2.35954869 -2.3595486  -2.35954851 -2.35954842 -2.35954833
#  -2.35954827 -2.35954817 -2.35954812 -2.35954803 -2.35954795 -2.35954786
#  -2.35954777 -2.35954769 -2.3595476  -2.35954752 -2.35954743 -2.35954732
#  -2.35954724 -2.35954716 -2.35954707 -2.35954699 -2.35954689 -2.35954683
#  -2.35954676 -2.35954665 -2.35954657 -2.35954647 -2.35954639 -2.35954629
#  -2.35954616 -2.35954606 -2.35954593 -2.3595458  -2.35954567 -2.35954557
#  -2.35954542 -2.35954528 -2.35954515 -2.35954498 -2.35954484 -2.3595447
#  -2.35954456 -2.35954438 -2.35954427 -2.35954409 -2.35954391 -2.35954372
#  -2.35954354 -2.35954332 -2.35954301 -2.35954277 -2.35954242 -2.35954192
#  -2.35954118 -2.35953503 -2.34488915 -2.33024586]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52129314 -2.38957449 -2.37490319 -2.36031329 -2.35935577 -2.35935553
#  -2.35935534 -2.3593552  -2.35935501 -2.35935487 -2.35935473 -2.35935459
#  -2.35935449 -2.35935435 -2.35935425 -2.3593542  -2.35935407 -2.35935398
#  -2.35935392 -2.35935383 -2.35935377 -2.35935365 -2.3593536  -2.35935354
#  -2.35935345 -2.35935337 -2.35935328 -2.35935323 -2.35935315 -2.35935307
#  -2.35935296 -2.35935287 -2.3593528  -2.35935271 -2.35935264 -2.35935256
#  -2.35935247 -2.35935237 -2.35935225 -2.35935217 -2.35935208 -2.35935198
#  -2.35935186 -2.35935176 -2.35935163 -2.35935153 -2.3593514  -2.3593513
#  -2.35935116 -2.35935106 -2.35935093 -2.35935086 -2.35935076 -2.35935059
#  -2.35935045 -2.35935031 -2.35935018 -2.35935    -2.35934986 -2.35934964
#  -2.35934949 -2.35934927 -2.35934908 -2.35934886 -2.35934878 -2.35934859
#  -2.35934831 -2.35934824 -2.35934792 -2.35934751 -2.35934667 -2.34567088
#  -2.33105997]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52152512 -2.38977754 -2.37510283 -2.36050952 -2.35955177 -2.35955153
#  -2.35955135 -2.3595512  -2.35955101 -2.35955087 -2.35955073 -2.35955059
#  -2.35955049 -2.35955035 -2.35955026 -2.3595502  -2.35955007 -2.35954998
#  -2.35954992 -2.35954983 -2.35954978 -2.35954966 -2.3595496  -2.35954954
#  -2.35954946 -2.35954937 -2.35954929 -2.35954923 -2.35954915 -2.35954907
#  -2.35954896 -2.35954888 -2.3595488  -2.35954872 -2.35954864 -2.35954856
#  -2.35954848 -2.35954838 -2.35954825 -2.35954817 -2.35954808 -2.35954799
#  -2.35954786 -2.35954776 -2.35954763 -2.35954753 -2.3595474  -2.3595473
#  -2.35954717 -2.35954707 -2.35954693 -2.35954686 -2.35954676 -2.35954659
#  -2.35954645 -2.35954632 -2.35954618 -2.359546   -2.35954586 -2.35954564
#  -2.35954549 -2.35954527 -2.35954509 -2.35954486 -2.35954478 -2.35954459
#  -2.35954432 -2.35954424 -2.35954392 -2.35954351 -2.35954267 -2.34586364
#  -2.33124925]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52037928 -2.38862649 -2.37399458 -2.35935581 -2.35935557 -2.35935538
#  -2.35935524 -2.35935505 -2.3593549  -2.35935476 -2.35935462 -2.35935452
#  -2.35935438 -2.35935429 -2.35935423 -2.3593541  -2.35935401 -2.35935395
#  -2.35935386 -2.3593538  -2.35935368 -2.35935363 -2.35935357 -2.35935348
#  -2.3593534  -2.35935331 -2.35935325 -2.35935317 -2.35935309 -2.35935298
#  -2.3593529  -2.35935282 -2.35935274 -2.35935266 -2.35935259 -2.3593525
#  -2.3593524  -2.3593523  -2.3593522  -2.35935211 -2.35935202 -2.35935189
#  -2.35935179 -2.35935166 -2.35935156 -2.35935143 -2.35935133 -2.3593512
#  -2.3593511  -2.35935096 -2.3593509  -2.3593508  -2.35935066 -2.35935049
#  -2.35935035 -2.35935021 -2.35935004 -2.35934989 -2.35934968 -2.35934953
#  -2.35934931 -2.35934912 -2.3593489  -2.35934882 -2.35934863 -2.35934835
#  -2.35934827 -2.35934796 -2.35934755 -2.35934672 -2.35933904 -2.34469662
#  -2.33005683]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52061107 -2.38882932 -2.37419401 -2.35955181 -2.35955157 -2.35955138
#  -2.35955124 -2.35955105 -2.3595509  -2.35955076 -2.35955063 -2.35955052
#  -2.35955039 -2.35955029 -2.35955023 -2.35955011 -2.35955001 -2.35954995
#  -2.35954986 -2.35954981 -2.35954969 -2.35954963 -2.35954957 -2.35954949
#  -2.3595494  -2.35954931 -2.35954925 -2.35954918 -2.3595491  -2.35954899
#  -2.35954891 -2.35954883 -2.35954875 -2.35954866 -2.35954859 -2.3595485
#  -2.3595484  -2.3595483  -2.3595482  -2.35954812 -2.35954802 -2.35954789
#  -2.35954779 -2.35954766 -2.35954756 -2.35954743 -2.35954733 -2.3595472
#  -2.3595471  -2.35954697 -2.3595469  -2.3595468  -2.35954666 -2.35954649
#  -2.35954635 -2.35954621 -2.35954604 -2.3595459  -2.35954568 -2.35954554
#  -2.35954531 -2.35954512 -2.3595449  -2.35954482 -2.35954463 -2.35954436
#  -2.35954428 -2.35954396 -2.35954355 -2.35954272 -2.35953503 -2.34488915
#  -2.33024586]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52129314 -2.38957449 -2.37490319 -2.36031329 -2.3593512  -2.35935092
#  -2.35935073 -2.35935058 -2.35935038 -2.3593502  -2.35935005 -2.35934991
#  -2.35934981 -2.35934967 -2.35934953 -2.35934943 -2.35934933 -2.35934924
#  -2.35934911 -2.35934901 -2.35934892 -2.35934882 -2.35934873 -2.35934867
#  -2.35934857 -2.35934845 -2.35934839 -2.3593483  -2.35934825 -2.35934816
#  -2.35934804 -2.35934796 -2.3593479  -2.35934778 -2.35934771 -2.35934762
#  -2.35934754 -2.35934745 -2.35934737 -2.35934729 -2.35934721 -2.3593471
#  -2.35934702 -2.35934691 -2.35934683 -2.35934676 -2.35934665 -2.35934658
#  -2.35934645 -2.35934639 -2.35934632 -2.35934619 -2.35934609 -2.35934595
#  -2.35934585 -2.35934572 -2.35934562 -2.35934548 -2.35934538 -2.35934524
#  -2.3593451  -2.35934496 -2.35934483 -2.35934465 -2.35934448 -2.3593443
#  -2.35934411 -2.35934393 -2.35934374 -2.35934352 -2.35934333 -2.35934314
#  -2.3593429  -2.35934274 -2.3593425  -2.35934205 -2.35934051 -2.34567088
#  -2.33105997]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52152512 -2.38977754 -2.37510283 -2.36050952 -2.35954721 -2.35954692
#  -2.35954673 -2.35954658 -2.35954639 -2.3595462  -2.35954605 -2.35954591
#  -2.35954581 -2.35954567 -2.35954553 -2.35954543 -2.35954533 -2.35954524
#  -2.35954511 -2.35954501 -2.35954492 -2.35954482 -2.35954473 -2.35954467
#  -2.35954458 -2.35954446 -2.35954439 -2.3595443  -2.35954425 -2.35954416
#  -2.35954404 -2.35954396 -2.35954391 -2.35954378 -2.35954371 -2.35954362
#  -2.35954354 -2.35954345 -2.35954337 -2.35954329 -2.35954321 -2.3595431
#  -2.35954302 -2.35954291 -2.35954283 -2.35954276 -2.35954266 -2.35954258
#  -2.35954245 -2.35954239 -2.35954232 -2.35954219 -2.35954209 -2.35954195
#  -2.35954185 -2.35954172 -2.35954162 -2.35954148 -2.35954138 -2.35954124
#  -2.3595411  -2.35954096 -2.35954083 -2.35954065 -2.35954048 -2.3595403
#  -2.35954011 -2.35953993 -2.35953974 -2.35953952 -2.35953933 -2.35953914
#  -2.3595389  -2.35953874 -2.3595385  -2.35953804 -2.35953651 -2.34586364
#  -2.33124925]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52037928 -2.38862649 -2.37399458 -2.35935125 -2.35935096 -2.35935077
#  -2.35935062 -2.35935042 -2.35935023 -2.35935009 -2.35934994 -2.35934984
#  -2.35934971 -2.35934956 -2.35934946 -2.35934937 -2.35934927 -2.35934914
#  -2.35934904 -2.35934895 -2.35934885 -2.35934876 -2.3593487  -2.35934861
#  -2.35934848 -2.35934842 -2.35934833 -2.35934827 -2.35934819 -2.35934807
#  -2.35934799 -2.35934793 -2.35934784 -2.35934773 -2.35934765 -2.35934756
#  -2.35934748 -2.3593474  -2.35934732 -2.35934723 -2.35934713 -2.35934705
#  -2.35934694 -2.35934686 -2.35934678 -2.35934668 -2.35934661 -2.35934648
#  -2.35934642 -2.35934635 -2.35934622 -2.35934612 -2.35934599 -2.35934589
#  -2.35934575 -2.35934565 -2.35934552 -2.35934541 -2.35934528 -2.35934514
#  -2.359345   -2.35934486 -2.35934472 -2.35934451 -2.35934434 -2.35934415
#  -2.35934396 -2.35934378 -2.35934355 -2.35934337 -2.35934317 -2.35934294
#  -2.35934278 -2.35934254 -2.35934209 -2.35934056 -2.35933904 -2.34469662
#  -2.33005683]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52061107 -2.38882932 -2.37419401 -2.35954725 -2.35954696 -2.35954677
#  -2.35954662 -2.35954642 -2.35954624 -2.35954609 -2.35954595 -2.35954585
#  -2.35954571 -2.35954557 -2.35954547 -2.35954537 -2.35954527 -2.35954514
#  -2.35954504 -2.35954495 -2.35954485 -2.35954476 -2.3595447  -2.35954461
#  -2.35954448 -2.35954442 -2.35954433 -2.35954427 -2.35954419 -2.35954407
#  -2.35954399 -2.35954393 -2.35954384 -2.35954373 -2.35954365 -2.35954357
#  -2.35954348 -2.3595434  -2.35954332 -2.35954323 -2.35954313 -2.35954305
#  -2.35954294 -2.35954286 -2.35954278 -2.35954268 -2.35954261 -2.35954248
#  -2.35954242 -2.35954236 -2.35954222 -2.35954212 -2.35954199 -2.35954189
#  -2.35954175 -2.35954165 -2.35954152 -2.35954142 -2.35954128 -2.35954114
#  -2.359541   -2.35954086 -2.35954072 -2.35954051 -2.35954034 -2.35954015
#  -2.35953996 -2.35953978 -2.35953956 -2.35953937 -2.35953917 -2.35953894
#  -2.35953878 -2.35953854 -2.35953809 -2.35953656 -2.35953503 -2.34488915
#  -2.33024586]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52129314 -2.38957449 -2.37490319 -2.36031329 -2.35935055 -2.35935026
#  -2.35935007 -2.35934984 -2.35934965 -2.35934946 -2.35934927 -2.35934913
#  -2.35934898 -2.35934884 -2.3593487  -2.35934857 -2.35934847 -2.35934833
#  -2.35934823 -2.35934809 -2.35934799 -2.35934793 -2.35934783 -2.35934774
#  -2.35934764 -2.35934755 -2.35934746 -2.35934737 -2.35934727 -2.35934721
#  -2.35934709 -2.35934704 -2.35934694 -2.35934683 -2.35934674 -2.35934662
#  -2.35934653 -2.35934645 -2.35934636 -2.35934628 -2.35934619 -2.35934612
#  -2.35934603 -2.35934595 -2.35934584 -2.35934576 -2.35934569 -2.35934559
#  -2.35934554 -2.35934546 -2.35934538 -2.35934527 -2.35934514 -2.35934504
#  -2.35934491 -2.35934481 -2.35934468 -2.35934454 -2.35934441 -2.35934426
#  -2.35934412 -2.35934399 -2.35934385 -2.35934371 -2.35934354 -2.3593434
#  -2.35934326 -2.35934311 -2.35934297 -2.35934279 -2.35934261 -2.35934242
#  -2.35934224 -2.35934197 -2.35934167 -2.35934138 -2.35934102 -2.35934073
#  -2.35934036 -2.35933953 -2.34567088 -2.33105997]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52152512 -2.38977754 -2.37510283 -2.36050952 -2.35954655 -2.35954627
#  -2.35954608 -2.35954584 -2.35954565 -2.35954546 -2.35954527 -2.35954513
#  -2.35954498 -2.35954484 -2.3595447  -2.35954457 -2.35954447 -2.35954433
#  -2.35954423 -2.35954409 -2.35954399 -2.35954393 -2.35954383 -2.35954374
#  -2.35954364 -2.35954355 -2.35954346 -2.35954337 -2.35954328 -2.35954322
#  -2.3595431  -2.35954304 -2.35954294 -2.35954283 -2.35954274 -2.35954262
#  -2.35954253 -2.35954245 -2.35954236 -2.35954228 -2.3595422  -2.35954212
#  -2.35954203 -2.35954195 -2.35954185 -2.35954176 -2.35954169 -2.35954159
#  -2.35954154 -2.35954146 -2.35954139 -2.35954127 -2.35954114 -2.35954104
#  -2.35954091 -2.35954081 -2.35954068 -2.35954054 -2.35954041 -2.35954026
#  -2.35954013 -2.35953999 -2.35953985 -2.35953971 -2.35953954 -2.3595394
#  -2.35953926 -2.35953911 -2.35953897 -2.35953879 -2.35953861 -2.35953842
#  -2.35953824 -2.35953797 -2.35953766 -2.35953738 -2.35953702 -2.35953673
#  -2.35953636 -2.35953553 -2.34586364 -2.33124925]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.52037928 -2.38862649 -2.37399458 -2.35935059 -2.35935031 -2.35935011
#  -2.35934988 -2.35934969 -2.3593495  -2.35934931 -2.35934916 -2.35934902
#  -2.35934887 -2.35934873 -2.3593486  -2.3593485  -2.35934836 -2.35934826
#  -2.35934813 -2.35934803 -2.35934796 -2.35934786 -2.35934777 -2.35934767
#  -2.35934758 -2.35934749 -2.3593474  -2.35934731 -2.35934725 -2.35934713
#  -2.35934706 -2.35934697 -2.35934686 -2.35934677 -2.35934668 -2.35934656
#  -2.35934648 -2.35934639 -2.35934631 -2.35934622 -2.35934614 -2.35934606
#  -2.35934598 -2.35934587 -2.35934579 -2.35934572 -2.35934561 -2.35934556
#  -2.35934548 -2.35934541 -2.35934533 -2.35934517 -2.35934507 -2.35934494
#  -2.35934484 -2.35934471 -2.35934458 -2.35934444 -2.3593443  -2.35934416
#  -2.35934402 -2.35934389 -2.35934375 -2.35934361 -2.35934343 -2.35934329
#  -2.35934315 -2.35934301 -2.35934282 -2.35934264 -2.35934246 -2.35934227
#  -2.35934201 -2.35934174 -2.35934142 -2.35934106 -2.35934077 -2.3593404
#  -2.35933958 -2.35933904 -2.34469662 -2.33005683]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.52061107 -2.38882932 -2.37419401 -2.35954659 -2.35954631 -2.35954611
#  -2.35954588 -2.35954569 -2.3595455  -2.35954531 -2.35954516 -2.35954502
#  -2.35954488 -2.35954474 -2.3595446  -2.3595445  -2.35954436 -2.35954426
#  -2.35954413 -2.35954403 -2.35954396 -2.35954387 -2.35954377 -2.35954367
#  -2.35954358 -2.35954349 -2.3595434  -2.35954331 -2.35954325 -2.35954313
#  -2.35954307 -2.35954297 -2.35954286 -2.35954277 -2.35954268 -2.35954256
#  -2.35954248 -2.35954239 -2.35954231 -2.35954222 -2.35954214 -2.35954206
#  -2.35954198 -2.35954187 -2.35954179 -2.35954172 -2.35954161 -2.35954156
#  -2.35954148 -2.35954141 -2.35954133 -2.35954117 -2.35954107 -2.35954094
#  -2.35954084 -2.35954071 -2.35954058 -2.35954044 -2.35954031 -2.35954016
#  -2.35954002 -2.35953989 -2.35953975 -2.35953961 -2.35953943 -2.35953929
#  -2.35953915 -2.35953901 -2.35953882 -2.35953864 -2.35953846 -2.35953827
#  -2.35953801 -2.35953774 -2.35953742 -2.35953706 -2.35953677 -2.3595364
#  -2.35953558 -2.35953503 -2.34488915 -2.33024586]
# iteration 2 completed (max 20)
# Corrected FITS file saved as ./reduced_output/6050390229/ni6050390229_0mpu7_cl_night_barycorr_orbit_gti.evt
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.1408424  -2.14084239 -2.14084238 ... -2.09584369 -2.09584368
#  -2.09584368]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.14098348 -2.14098347 -2.14098347 ... -2.09597271 -2.0959727
#  -2.0959727 ]
# iteration 2 completed (max 20)
# Romer Delay:  [0.00062187 0.00062187 0.00062187 ... 0.00056867 0.00056867 0.00056867]
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.1408424  -2.12619209 -2.11153652 -2.09694136]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.14098348 -2.12632927 -2.11166978 -2.09707067]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.13976309 -2.12512066 -2.11048086 -2.09584368]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.1399039  -2.12525756 -2.11061383 -2.09597269]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.1408424  -2.12619209 -2.11153652]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.14098348 -2.12632927 -2.11166978]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.13976309 -2.12512066 -2.11048086]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.1399039  -2.12525756 -2.11061383]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.12619209 -2.11153652]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.12632927 -2.11166978]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.12512066 -2.11048086]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.12525756 -2.11061383]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.12619209 -2.11153652]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.12632927 -2.11166978]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.12512066 -2.11048086]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.12525756 -2.11061383]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.12619209 -2.11153652 -2.09694136]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.12632927 -2.11166978 -2.09707067]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.12512066 -2.11048086 -2.09584368]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.12525756 -2.11061383 -2.09597269]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.1408424  -2.12619209 -2.11153652 -2.09694136]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.14098348 -2.12632927 -2.11166978 -2.09707067]
# ...
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.05076768]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.05078279]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.05130341]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.05131834]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.03611945 1.05076768 1.07996174 1.09461785 1.15311888]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.03613914 1.05078279 1.0799677  1.09461922 1.15310192]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.03666567 1.05130341 1.08057887 1.0952166  1.15376753]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.03668519 1.05131834 1.08058464 1.09521778 1.15375036]
# iteration 2 completed (max 20)
# Corrected FITS file saved as ./reduced_output/6050390270/ni6050390270_0mpu7_cl_night_barycorr_orbit_gti.evt
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.63558884 1.63558885 1.63558886 ... 1.6513793  1.6513794  1.65137942]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63542881 1.63542882 1.63542883 ... 1.65121504 1.65121513 1.65121516]
# iteration 2 completed (max 20)
# Romer Delay:  [0.00070536 0.00070536 0.00070536 ... 0.00072402 0.00072402 0.00072402]
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.63558884 1.65022657]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63542881 1.65006261]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.6367417  1.65137942]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63658136 1.65121516]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.63558884 1.65022657]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63542881 1.65006261]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.6367417  1.65137942]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63658136 1.65121516]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.63558884 1.65022657]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63542881 1.65006261]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.6367417  1.65137942]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63658136 1.65121516]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.63558884 1.65022657]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63542881 1.65006261]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.6367417  1.65137942]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63658136 1.65121516]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.63558884 1.65022657]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63542881 1.65006261]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.6367417  1.65137942]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63658136 1.65121516]
# iteration 2 completed (max 20)
# Skipping empty GTI HDU 8 in file ./reduced_output/6050390272/ni6050390272_0mpu7_cl_night_barycorr.evt
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.63558884 1.65022657]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63542881 1.65006261]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.6367417  1.65137942]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63658136 1.65121516]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.63558884 1.65022657]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63542881 1.65006261]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.6367417  1.65137942]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63658136 1.65121516]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.63558884 1.65022657]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63542881 1.65006261]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.6367417  1.65137942]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63658136 1.65121516]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.63558884 1.65022657]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63542881 1.65006261]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.6367417  1.65137942]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63658136 1.65121516]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.63558884 1.65022657]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63542881 1.65006261]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.6367417  1.65137942]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63658136 1.65121516]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.63558884 1.65022657]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63542881 1.65006261]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [1.6367417  1.65137942]
# iteration 1 completed (max 20)
# Mean Anomaly: [1.63658136 1.65121516]
# iteration 2 completed (max 20)
# Corrected FITS file saved as ./reduced_output/6050390272/ni6050390272_0mpu7_cl_night_barycorr_orbit_gti.evt
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [2.70373016 2.70373027 2.70373031 ... 2.7784338  2.77843385 2.77843386]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.70339913 2.70339923 2.70339927 ... 2.77810096 2.77810101 2.77810103]
# iteration 2 completed (max 20)
# Romer Delay:  [0.0014591  0.0014591  0.0014591  ... 0.00146704 0.00146704 0.00146704]
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [2.70373015 2.70512199 2.71920822 2.7320628  2.74763541 2.76341285
#  2.77806895 2.77827641]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.70339912 2.7047909  2.7188767  2.73173092 2.74730315 2.76308027
#  2.77773612 2.77794358]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [2.70508522 2.70522965 2.71986737 2.73451821 2.74915592 2.76379364
#  2.77827116 2.77843397]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.70475414 2.70489857 2.71953582 2.73418626 2.74882363 2.76346104
#  2.77793832 2.77810114]
# iteration 2 completed (max 20)
# Skipping empty GTI HDU 4 in file ./reduced_output/6050390276/ni6050390276_0mpu7_cl_night_barycorr.evt
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [2.70373015 2.70512199 2.71920822 2.7320628  2.74763541 2.76341285
#  2.77806895 2.77827641]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.70339912 2.7047909  2.7188767  2.73173092 2.74730315 2.76308027
#  2.77773612 2.77794358]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [2.70508522 2.70522965 2.71986737 2.73451821 2.74915592 2.76379364
#  2.77827116 2.77843397]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.70475414 2.70489857 2.71953582 2.73418626 2.74882363 2.76346104
#  2.77793832 2.77810114]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [2.7320628  2.74763541 2.76341285 2.77806895 2.77827641]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.73173092 2.74730315 2.76308027 2.77773612 2.77794358]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [2.73451821 2.74915592 2.76379364 2.77827116 2.77843397]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.73418626 2.74882363 2.76346104 2.77793832 2.77810114]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [2.70373015 2.70512199 2.71920822 2.7320628  2.74763541 2.76341285
#  2.77806895 2.77827641]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.70339912 2.7047909  2.7188767  2.73173092 2.74730315 2.76308027
#  2.77773612 2.77794358]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [2.70508522 2.70522965 2.71986737 2.73451821 2.74915592 2.76379364
#  2.77827116 2.77843397]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.70475414 2.70489857 2.71953582 2.73418626 2.74882363 2.76346104
#  2.77793832 2.77810114]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [2.71920822 2.7320628  2.74763541 2.76341285 2.77806895 2.77827641]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.7188767  2.73173092 2.74730315 2.76308027 2.77773612 2.77794358]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [2.71986737 2.73451821 2.74915592 2.76379364 2.77827116 2.77843397]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.71953582 2.73418626 2.74882363 2.76346104 2.77793832 2.77810114]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [2.7320628  2.74763541 2.76341285 2.77806895 2.77827641]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.73173092 2.74730315 2.76308027 2.77773612 2.77794358]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [2.73451821 2.74915592 2.76379364 2.77827116 2.77843397]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.73418626 2.74882363 2.76346104 2.77793832 2.77810114]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [2.70373015 2.70512199 2.71920822 2.7320628  2.74763541 2.76341285
#  2.77806895 2.77827641]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.70339912 2.7047909  2.7188767  2.73173092 2.74730315 2.76308027
#  2.77773612 2.77794358]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [2.70508522 2.70522965 2.71986737 2.73451821 2.74915592 2.76379364
#  2.77827116 2.77843397]
# iteration 1 completed (max 20)
# Mean Anomaly: [2.70475414 2.70489857 2.71953582 2.73418626 2.74882363 2.76346104
#  2.77793832 2.77810114]
# iteration 2 completed (max 20)
# Corrected FITS file saved as ./reduced_output/6050390276/ni6050390276_0mpu7_cl_night_barycorr_orbit_gti.evt
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.96429578 -2.96429568 -2.96429565 ... -2.90447687 -2.90447679
#  -2.90447672]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.96460048 -2.96460038 -2.96460035 ... -2.90477418 -2.90477411
#  -2.90477404]
# iteration 2 completed (max 20)
# Romer Delay:  [0.00134302 0.00134302 0.00134302 ... 0.00131048 0.00131048 0.00131048]
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.96429588 -2.94900165 -2.93504673 -2.93431405 -2.92034338 -2.90595253]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.96460058 -2.94930454 -2.93534792 -2.93461516 -2.92064273 -2.90625004]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.96305111 -2.94840816 -2.93433769 -2.93376521 -2.91912225 -2.90447667]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.96335567 -2.94871098 -2.93463879 -2.93406624 -2.91942145 -2.90477399]
# iteration 2 completed (max 20)
# Skipping empty GTI HDU 4 in file ./reduced_output/6050390279/ni6050390279_0mpu7_cl_night_barycorr.evt
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.96429588 -2.94900165 -2.93504673 -2.93431405 -2.92034338 -2.90595253]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.96460058 -2.94930454 -2.93534792 -2.93461516 -2.92064273 -2.90625004]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.96305111 -2.94840816 -2.93433769 -2.93376521 -2.91912225 -2.90447667]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.96335567 -2.94871098 -2.93463879 -2.93406624 -2.91942145 -2.90477399]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.96429588 -2.94900165 -2.93504673 -2.93431405 -2.92034338 -2.90595253]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.96460058 -2.94930454 -2.93534792 -2.93461516 -2.92064273 -2.90625004]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.96305111 -2.94840816 -2.93433769 -2.93376521 -2.91912225 -2.90447667]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.96335567 -2.94871098 -2.93463879 -2.93406624 -2.91942145 -2.90477399]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.96429588 -2.94900165 -2.93504673 -2.93431405 -2.92034338 -2.90595253]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.96460058 -2.94930454 -2.93534792 -2.93461516 -2.92064273 -2.90625004]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.96305111 -2.94840816 -2.93433769 -2.93376521 -2.91912225 -2.90447667]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.96335567 -2.94871098 -2.93463879 -2.93406624 -2.91942145 -2.90477399]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.96429588 -2.94900165 -2.93504673 -2.93431405 -2.92034338 -2.90595253]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.96460058 -2.94930454 -2.93534792 -2.93461516 -2.92064273 -2.90625004]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.96305111 -2.94840816 -2.93433769 -2.93376521 -2.91912225 -2.90447667]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.96335567 -2.94871098 -2.93463879 -2.93406624 -2.91942145 -2.90477399]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.96429588 -2.94900165 -2.93504673 -2.93431405 -2.92034338 -2.90595253]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.96460058 -2.94930454 -2.93534792 -2.93461516 -2.92064273 -2.90625004]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.96305111 -2.94840816 -2.93433769 -2.93376521 -2.91912225 -2.90447667]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.96335567 -2.94871098 -2.93463879 -2.93406624 -2.91942145 -2.90477399]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.96429588 -2.94900165 -2.93504673 -2.93431405 -2.92034338 -2.90595253]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.96460058 -2.94930454 -2.93534792 -2.93461516 -2.92064273 -2.90625004]
# iteration 2 completed (max 20)
# -1
# 58103.476861347226 Debugging time
# starting iterations (max 20)
# Mean Anomaly: [-2.96305111 -2.94840816 -2.93433769 -2.93376521 -2.91912225 -2.90447667]
# iteration 1 completed (max 20)
# Mean Anomaly: [-2.96335567 -2.94871098 -2.93463879 -2.93406624 -2.91942145 -2.90477399]
# iteration 2 completed (max 20)
# Corrected FITS file saved as ./reduced_output/6050390279/ni6050390279_0mpu7_cl_night_barycorr_orbit_gti.evt

# %%
input_times_flat = np.concatenate(input_times)
corrected_times_flat = np.concatenate(corrected_times)

# %%
delays=(input_times_flat-corrected_times_flat)*86400.

# %%
delays
